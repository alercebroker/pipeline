# %%
import pandas as pd

# %%
rubin = pd.read_pickle('/home/dmoreno/pipeline_v4_final/pipeline/training/stamp_classifier/data_acquisition/rubin/data/processed/rubin_AGN_vs_VS/firststamps_250708.pkl')

# %%
rubin
# Out:
#              diaObjectId         diaSourceId    coord_ra  coord_dec class  \
# 0     579574500513808385  600390539342250009    6.468946 -72.665752    VS
# 1     579574500513808418  600443307042013226    6.468619 -72.666153    VS
# 2     579574500513808420  600443307042013237    6.702619 -72.673818    VS
# 3     579574569233285135  600390539476467760    6.011728 -72.654608    VS
# 4     579574569233285165  600394932692189194    5.816260 -72.665276    VS
# ...                  ...                 ...         ...        ...   ...
# 2522  630406022577521011  600425736869249290  106.155574 -10.406804    VS
# 2523  630406022577522069  600425737672983470  106.013800 -10.376323    VS
# 2524  630406709772299359  600465369349489739  106.135690 -10.301897    VS
# 2525  630407534406008861  600456548157751477  105.804489 -10.069484    VS
# 2526  630407534406008877  600456548157751603  105.783760 -10.120368    VS
#
#             snr       psfFlux   psfFluxErr   scienceFlux  scienceFluxErr  \
# ...
