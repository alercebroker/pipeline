# %%
# %cd ../
# Out:
# /home/dmoreno/pipeline_v4_final/pipeline/training/stamp_classifier/data_acquisition

# %%
import pandas as pd

# %%
test_first_stamps_fixed = pd.read_pickle('data/test_first_stamps_fixed.pkl')
test_first_stamps_fixed
# Out:
#                oid               candid          ra        dec  \
# 0     ZTF18acrvifj   696386371515015013   97.911473  44.166678
# 1     ZTF20abkxmgb  1288219222015015013  226.357595  46.980558
# 2     ZTF19acarncj   996206012515010011  310.241926 -17.263419
# 3     ZTF20aawjbfj  1211173763415015012  153.997027  26.575844
# 4     ZTF19aacwhdf   739437341315015051  141.613111  16.308071
# ...            ...                  ...         ...        ...
# 9857  ZTF18aagwylf              unknown  253.952703  23.838335
# 9858  ZTF18aarkrua              unknown  164.455587   9.003795
# 9859  ZTF18aapwhnu              unknown  274.923856  46.905797
# 9860  ZTF18aaipkfp              unknown  222.682940  38.877842
# 9861  ZTF18aagxsix              unknown  254.137592  40.940354
#
#                                                 science  \
# 0     [[150.61218, 156.52292, 147.70602, 176.33075, ...
# 1     [[246.61423, 243.23764, 235.10992, 246.75642, ...
# ...

# %%
test_first_stamps_dataset = pd.read_pickle('data/test_first_stamps_dataset.pkl')
test_first_stamps_dataset
# Out:
#                            candid          ra        dec  \
# oid
# ZTF18acrvifj   696386371515015013   97.911473  44.166678
# ZTF20abkxmgb  1288219222015015013  226.357595  46.980558
# ZTF19acarncj   996206012515010011  310.241926 -17.263419
# ZTF20aawjbfj  1211173763415015012  153.997027  26.575844
# ZTF19aacwhdf   739437341315015051  141.613111  16.308071
# ...                           ...         ...        ...
# ZTF18aagwylf              unknown  253.952703  23.838335
# ZTF18aarkrua              unknown  164.455587   9.003795
# ZTF18aapwhnu              unknown  274.923856  46.905797
# ZTF18aaipkfp              unknown  222.682940  38.877842
# ZTF18aagxsix              unknown  254.137592  40.940354
#
#                                                         science  \
# oid
# ZTF18acrvifj  [[150.61218, 156.52292, 147.70602, 176.33075, ...
# ZTF20abkxmgb  [[246.61423, 243.23764, 235.10992, 246.75642, ...
# ZTF19acarncj  [[136.94568, 133.78656, 131.76529, 126.81133, ...
# ...

# %%
consolidated_dataset = pd.read_pickle('data/processed/consolidated_dataset.pkl')
consolidated_dataset
# Out:
#              oid               candid          ra        dec  \
# 11  ZTF21aaebkmj  1501128131215015004   65.163495 -26.636435
# 14  ZTF18abtnlik   643114394415015053  279.321654  49.148389
# 9   ZTF19acjurot  1058126442015015014  320.853375 -17.720127
# 15  ZTF20aanvpzo  1200441200215015003  224.375994   8.389928
# 19  ZTF20aawxpru  1306411870015015009  322.840280   9.429956
# ..           ...                  ...         ...        ...
# 0   ZTF19acrcngf  1043073070615015017  287.896865 -13.058972
# 0   ZTF19acrdiud  1043169350415015017  359.363247   2.152355
# 0   ZTF19acrdyfr  1043265262115015067   72.337484  54.630553
# 0   ZTF19acrqqvl  1044312843715015025  110.675771  48.877886
# 0   ZTF19acrydac  1046210042515015007   24.930835 -10.105637
#
#                                               science  \
# 11  [[404.2104, 394.65637, 403.2213, 391.0437, 396...
# 14  [[79.67049, 86.467064, 78.972015, 81.246994, 8...
# 9   [[113.59538, 131.67825, 126.9975, 119.60596, 1...
# ...

# %%
a = consolidated_dataset[consolidated_dataset.oid.isin(test_first_stamps_fixed.oid.values)]
a
# Out:
#              oid               candid          ra        dec  \
# 14  ZTF18abtnlik   643114394415015053  279.321654  49.148389
# 14  ZTF18abmrhom   624275525915015005  325.047009  21.558326
# 59  ZTF20abjyoty  1433229102115015005   23.644589  -3.343752
# 43  ZTF19aabyppp   858191575015015000  175.690612  21.714840
# 21  ZTF20acobevy  1445105054315015001    0.562998 -23.495017
# ..           ...                  ...         ...        ...
# 0   ZTF19acftdhz  1020195631015015012  342.574051   1.077047
# 0   ZTF19acqxshs  1042127545015015002  307.763928 -14.329139
# 0   ZTF19acqykmb  1042291142015015017   94.146447  11.340186
# 0   ZTF19acrdyfr  1043265262115015067   72.337484  54.630553
# 0   ZTF19acrydac  1046210042515015007   24.930835 -10.105637
#
#                                               science  \
# 14  [[79.67049, 86.467064, 78.972015, 81.246994, 8...
# 14  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 59  [[194.92285, 217.65775, 208.12668, 214.41992, ...
# ...

# %%
a['s'] = a['science'].apply(lambda x: x.shape)
a = a[a['s'] == (63, 63)]
a.drop_duplicates(subset=["oid"], keep='first', inplace=True)
a
# Out:
# /tmp/ipykernel_949498/3473593462.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['s'] = a['science'].apply(lambda x: x.shape)
#              oid               candid          ra        dec  \
# 14  ZTF18abtnlik   643114394415015053  279.321654  49.148389
# 14  ZTF18abmrhom   624275525915015005  325.047009  21.558326
# 59  ZTF20abjyoty  1433229102115015005   23.644589  -3.343752
# 43  ZTF19aabyppp   858191575015015000  175.690612  21.714840
# 21  ZTF20acobevy  1445105054315015001    0.562998 -23.495017
# ..           ...                  ...         ...        ...
# 0   ZTF19acftdhz  1020195631015015012  342.574051   1.077047
# 0   ZTF19acqxshs  1042127545015015002  307.763928 -14.329139
# ...
