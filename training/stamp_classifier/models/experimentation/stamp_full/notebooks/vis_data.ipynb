# %%
# %cd ../
# Out:
# /home/dmoreno/pipeline_v4_final/pipeline/training/stamp_classifier/models/experimentation/stamp_full

# %%
import pandas as pd

# %%
normalized_ndarrays = pd.read_pickle('data/normalized_ndarrays.pkl')
normalized_ndarrays.keys()
# Out:
# dict_keys(['x_train', 'pos_train', 'y_train', 'oid_train', 'x_val', 'pos_val', 'y_val', 'oid_val', 'x_test', 'pos_test', 'y_test', 'oid_test', 'label_encoder'])

# %%
print(len(normalized_ndarrays['oid_train']))
print(len(normalized_ndarrays['oid_test']))
print(len(normalized_ndarrays['oid_val']))
# Out:
# 29586
# 9862
# 9862

# %%
len(normalized_ndarrays['oid_train']) + len(normalized_ndarrays['oid_test']) + len(normalized_ndarrays['oid_val'])
# Out:
# 49310

# %%
metadata_oids = pd.read_parquet('data/full_stamp_classifier_oids.parquet')
metadata_oids
# Out:
#                 oid               candid          ra        dec      class
# 0      ZTF21aaebkmj  1501128131215015004   65.163495 -26.636435         SN
# 1      ZTF18abtnlik   643114394415015053  279.321654  49.148389         SN
# 2      ZTF19acjurot  1058126442015015014  320.853375 -17.720127         SN
# 3      ZTF20aanvpzo  1200441200215015003  224.375994   8.389928         SN
# 4      ZTF20aawxpru  1306411870015015009  322.840280   9.429956         SN
# ...             ...                  ...         ...        ...        ...
# 50920  ZTF19acrcngf  1043073070615015017  287.896865 -13.058972  satellite
# 50921  ZTF19acrdiud  1043169350415015017  359.363247   2.152355  satellite
# 50922  ZTF19acrdyfr  1043265262115015067   72.337484  54.630553  satellite
# 50923  ZTF19acrqqvl  1044312843715015025  110.675771  48.877886  satellite
# 50924  ZTF19acrydac  1046210042515015007   24.930835 -10.105637  satellite
#
# [50925 rows x 5 columns]

# %%
metadata_oids[metadata_oids.oid.isin(
    ['ZTF21abawbuw', 'ZTF21acoiffz', 'ZTF21abuxlyn', 'ZTF21abdxbqf',
    'ZTF19acdtlwm', 'ZTF21abmwkhz', 'ZTF19acdulfn', 'ZTF21abagjlk',
    'ZTF21abcagnl', 'ZTF19acdtlxq', 'ZTF21aanwldq', 'ZTF19acdmbmh',
    'ZTF19abzymqm', 'ZTF21aarjnhx', 'ZTF21abcjklk', 'ZTF19acftdhz',
    'ZTF21abawwba', 'ZTF21acljxhw', 'ZTF21acoqkop', 'ZTF21abrqcla',
    'ZTF21aanwemu', 'ZTF19ackbfwc', 'ZTF21abmooqy', 'ZTF21aayqzzg',
    'ZTF19acexmzq', 'ZTF21aaqlufs']
)]
# Out:
#                 oid               candid          ra        dec      class
# 50348  ZTF21aanwemu  1521392755815015005  202.767314  64.176636  satellite
# 50353  ZTF21aanwldq  1521483731715015007  258.227078 -17.176382  satellite
# 50439  ZTF21aaqlufs  1541377245915015020  191.894879 -22.025096  satellite
# 50456  ZTF21aarjnhx  1551474672515015157  296.280596  32.489568  satellite
# 50489  ZTF21aayqzzg  1584380475615015009  223.422384  22.432246  satellite
# 50499  ZTF21abagjlk  1589344715715015016  284.225802  65.728147  satellite
# 50510  ZTF21abawbuw  1591425675815015047  311.092870  13.938715  satellite
# 50511  ZTF21abawwba  1591474540215015009  318.457067 -12.948145  satellite
# 50523  ZTF21abcagnl  1599461822715015020  312.054343  10.502480  satellite
# 50533  ZTF21abcjklk  1605182754715015011  154.199228  -2.398626  satellite
# 50569  ZTF21abdxbqf  1615225865915015020  170.343607  -0.216518  satellite
# 50716  ZTF21abmooqy  1658332112215015028  302.284459  68.145087  satellite
# 50720  ZTF21abmwkhz  1660396183215015037  293.920646  34.398185  satellite
# 50746  ZTF21abrqcla  1680476420915015024   22.441194  23.321546  satellite
# 50756  ZTF21abuxlyn  1695383183715015014   18.030394  56.206556  satellite
# 50823  ZTF21acljxhw  1768542614115015014  185.302283  13.133088  satellite
# 50843  ZTF21acoiffz  1773531652415015005  174.359150 -10.234487  satellite
# 50850  ZTF21acoqkop  1775549000215015011  194.217640   0.992151  satellite
# 50881  ZTF19abzymqm   993418745815015014   32.169843  -7.227370  satellite
# 50892  ZTF19acdmbmh  1010144713015015015  308.478230  53.781193  satellite
# 50893  ZTF19acdtlwm  1010485252715015155  120.505837  -4.379112  satellite
# 50894  ZTF19acdtlxq  1010485252715015154  120.508515  -4.379491  satellite
# 50900  ZTF19acdulfn  1011097451415015000  280.256328 -19.920166  satellite
# 50910  ZTF19acexmzq  1018338711715015035   88.117270  10.964809  satellite
# 50912  ZTF19acftdhz  1020195631015015012  342.574051   1.077047  satellite
# 50913  ZTF19ackbfwc  1031323944415015010   20.486838  -1.015748  satellite

# %%
metadata_hasavro = pd.read_parquet('data/full_stamp_classifier_metadata_hasavro.parquet')
metadata_hasavro
# Out:
#                 oid               candid          ra        dec       gal_l  \
# 0      ZTF21aaebkmj  1501128131215015004   65.163495 -26.636435  224.888336
# 1      ZTF18abtnlik   643114394415015053  279.321654  49.148389   78.016574
# 2      ZTF19acjurot  1058126442015015014  320.853375 -17.720127   32.664194
# 3      ZTF20aanvpzo  1200441200215015003  224.375994   8.389928    6.711000
# 4      ZTF20aawxpru  1306411870015015009  322.840280   9.429956   62.842008
# ...             ...                  ...         ...        ...         ...
# 49125  ZTF19acrcngf  1043073070615015017  287.896865 -13.058972   23.448670
# 49126  ZTF19acrdiud  1043169350415015017  359.363247   2.152355   96.853290
# 49127  ZTF19acrdyfr  1043265262115015067   72.337484  54.630553  153.044004
# 49128  ZTF19acrqqvl  1044312843715015025  110.675771  48.877886  168.911325
# 49129  ZTF19acrydac  1046210042515015007   24.930835 -10.105637  158.985254
#
#            gal_b    ecl_long    ecl_lat     magpsf  sigmapsf  ...  sgscore1  \
# 0     -43.699489   56.438373 -47.223415  19.800232  0.179855  ...  0.500000
# 1      22.385199  289.985625  71.941418  20.333069  0.180506  ...  0.001250
# 2     -41.349474  317.674423  -2.295138  18.519318  0.107349  ...  0.009167
# 3      54.797328  219.201834  24.147229  19.587193  0.166170  ...  0.763083
# 4     -29.301685  328.512798  22.789567  20.299837  0.208037  ...  0.500000
# ...          ...         ...        ...        ...       ...  ...       ...
# 49125 -10.320624  287.658060   9.289962  17.936604  0.088779  ...  0.646083
# 49126 -57.959728    0.272379   2.227941  18.803501  0.181385  ...  0.001875
# 49127   6.326199   78.058172  31.921084  19.165157  0.193813  ...  0.964786
# 49128  25.030347  105.040261  26.512481  16.571047  0.050797  ...  0.145137
# 49129 -69.523392   19.203282 -19.029566  16.762112  0.093249  ...  0.500000
#
#        sgscore2  sgscore3  distpsnr1  distpsnr2  distpsnr3  ndethist  \
# 0      0.001250  0.500000   5.558571   6.079560   7.264775        12
# 1      0.994167  0.997250   5.262714   6.867275   9.061376       150
# 2      0.500000  0.000000   0.008522   0.558093   7.119209        10
# 3      0.500000  0.107167   8.462006   9.868366  10.590695        13
# 4      0.254470  0.140304   5.226012   5.712976   8.442719        43
# ...         ...       ...        ...        ...        ...       ...
# 49125  0.938863  0.694062   2.037887   2.453805   3.977600         1
# 49126  0.500000  0.033952   2.019713   4.380590  14.092403         1
# 49127  0.995417  0.997417   3.916241  10.256860  12.908553         1
# 49128  0.229018  0.988542   2.520166   8.693634  14.109303         1
# 49129  0.500000  0.006250   2.979559   3.440451   5.720247         1
#
#        ncovhist  chinr  sharpnr
# 0           232  3.333    0.240
# 1           960  2.963    0.086
# 2           133  1.575    0.042
# 3           345  1.611    0.367
# 4           422  7.562    0.575
# ...         ...    ...      ...
# 49125       599  0.484   -0.019
# 49126       334  3.329    0.248
# 49127       456  0.633   -0.025
# 49128       371  7.370    0.283
# 49129       190  5.594    0.605
#
# [49130 rows x 24 columns]

# %%
metadata_hasavro.isnull().sum()
# Out:
# oid           0
# candid        0
# ra            0
# dec           0
# gal_l         0
# gal_b         0
# ecl_long      0
# ecl_lat       0
# magpsf        0
# sigmapsf      0
# isdiffpos     0
# diffmaglim    0
# classtar      0
# fwhm          0
# sgscore1      0
# sgscore2      0
# sgscore3      0
# distpsnr1     0
# distpsnr2     0
# distpsnr3     0
# ndethist      0
# ncovhist      0
# chinr         0
# sharpnr       0
# dtype: int64

# %%
metadata_noavro = pd.read_parquet('data/full_stamp_classifier_metadata_noavro.parquet')
metadata_noavro
# Out:
#                oid               candid          ra        dec       gal_l  \
# 0     ZTF18aabpsir  1553327823715010004  215.122661  48.956516   90.673105
# 1     ZTF18abvhzvu  1617442404715010014  308.469050  19.511793   62.541009
# 2     ZTF18abcqldl  1721229641415010007  277.156621 -12.851467   18.917937
# 3     ZTF19aaepnzl   755188833715015010   79.705286  -1.328569  203.141684
# 4     ZTF18aabcdug              unknown  151.621987  50.547540  164.680931
# ...            ...                  ...         ...        ...         ...
# 1790  ZTF18aarvhyg              unknown  256.956085  39.436829   63.570722
# 1791  ZTF18aatdcqo              unknown  126.808987  25.724485  198.001382
# 1792  ZTF18aatmzvi              unknown  284.974359  44.981763   75.135763
# 1793  ZTF18aatnjsg              unknown  250.386926  36.476340   59.024970
# 1794  ZTF18aaulvju              unknown  244.412102  30.524040   50.050632
#
#           gal_b    ecl_long    ecl_lat
# 0     62.219283  184.958683  57.378207
# 1    -12.139631  317.134538  36.869327
# 2     -0.870914  277.093837  10.411756
# 3    -21.126469   78.689204 -24.364544
# 4     51.019467  133.739346  36.036546
# ...         ...         ...        ...
# 1790  36.152051  248.282264  61.896232
# 1791  31.559648  122.897930   6.391194
# 1792  17.403278  297.861494  66.978337
# 1793  40.942623  239.513923  57.857825
# 1794  45.096258  233.931728  50.808172
#
# [1795 rows x 8 columns]

# %%
metadata_noavro.isnull().sum()
# Out:
# oid         0
# candid      0
# ra          0
# dec         0
# gal_l       0
# gal_b       0
# ecl_long    0
# ecl_lat     0
# dtype: int64

# %%
metadata = pd.concat([metadata_hasavro, metadata_noavro])
metadata.isnull().sum()
# Out:
# oid              0
# candid           0
# ra               0
# dec              0
# gal_l            0
# gal_b            0
# ecl_long         0
# ecl_lat          0
# magpsf        1795
# sigmapsf      1795
# isdiffpos     1795
# diffmaglim    1795
# classtar      1795
# fwhm          1795
# sgscore1      1795
# sgscore2      1795
# sgscore3      1795
# distpsnr1     1795
# distpsnr2     1795
# distpsnr3     1795
# ndethist      1795
# ncovhist      1795
# chinr         1795
# sharpnr       1795
# dtype: int64

# %%
metadata['non_detections'] = metadata['ncovhist'] - metadata['ndethist']
metadata
# Out:
#                oid               candid          ra        dec       gal_l  \
# 0     ZTF21aaebkmj  1501128131215015004   65.163495 -26.636435  224.888336
# 1     ZTF18abtnlik   643114394415015053  279.321654  49.148389   78.016574
# 2     ZTF19acjurot  1058126442015015014  320.853375 -17.720127   32.664194
# 3     ZTF20aanvpzo  1200441200215015003  224.375994   8.389928    6.711000
# 4     ZTF20aawxpru  1306411870015015009  322.840280   9.429956   62.842008
# ...            ...                  ...         ...        ...         ...
# 1790  ZTF18aarvhyg              unknown  256.956085  39.436829   63.570722
# 1791  ZTF18aatdcqo              unknown  126.808987  25.724485  198.001382
# 1792  ZTF18aatmzvi              unknown  284.974359  44.981763   75.135763
# 1793  ZTF18aatnjsg              unknown  250.386926  36.476340   59.024970
# 1794  ZTF18aaulvju              unknown  244.412102  30.524040   50.050632
#
#           gal_b    ecl_long    ecl_lat     magpsf  sigmapsf  ...  sgscore2  \
# 0    -43.699489   56.438373 -47.223415  19.800232  0.179855  ...  0.001250
# 1     22.385199  289.985625  71.941418  20.333069  0.180506  ...  0.994167
# 2    -41.349474  317.674423  -2.295138  18.519318  0.107349  ...  0.500000
# 3     54.797328  219.201834  24.147229  19.587193  0.166170  ...  0.500000
# 4    -29.301685  328.512798  22.789567  20.299837  0.208037  ...  0.254470
# ...         ...         ...        ...        ...       ...  ...       ...
# 1790  36.152051  248.282264  61.896232        NaN       NaN  ...       NaN
# 1791  31.559648  122.897930   6.391194        NaN       NaN  ...       NaN
# 1792  17.403278  297.861494  66.978337        NaN       NaN  ...       NaN
# 1793  40.942623  239.513923  57.857825        NaN       NaN  ...       NaN
# 1794  45.096258  233.931728  50.808172        NaN       NaN  ...       NaN
#
#       sgscore3  distpsnr1  distpsnr2  distpsnr3  ndethist  ncovhist  chinr  \
# 0     0.500000   5.558571   6.079560   7.264775      12.0     232.0  3.333
# 1     0.997250   5.262714   6.867275   9.061376     150.0     960.0  2.963
# 2     0.000000   0.008522   0.558093   7.119209      10.0     133.0  1.575
# 3     0.107167   8.462006   9.868366  10.590695      13.0     345.0  1.611
# 4     0.140304   5.226012   5.712976   8.442719      43.0     422.0  7.562
# ...        ...        ...        ...        ...       ...       ...    ...
# 1790       NaN        NaN        NaN        NaN       NaN       NaN    NaN
# 1791       NaN        NaN        NaN        NaN       NaN       NaN    NaN
# 1792       NaN        NaN        NaN        NaN       NaN       NaN    NaN
# 1793       NaN        NaN        NaN        NaN       NaN       NaN    NaN
# 1794       NaN        NaN        NaN        NaN       NaN       NaN    NaN
#
#       sharpnr  non_detections
# 0       0.240           220.0
# 1       0.086           810.0
# 2       0.042           123.0
# 3       0.367           332.0
# 4       0.575           379.0
# ...       ...             ...
# 1790      NaN             NaN
# 1791      NaN             NaN
# 1792      NaN             NaN
# 1793      NaN             NaN
# 1794      NaN             NaN
#
# [50925 rows x 25 columns]

# %%
metadata = metadata.fillna(-999)
metadata
# Out:
#                oid               candid          ra        dec       gal_l  \
# 0     ZTF21aaebkmj  1501128131215015004   65.163495 -26.636435  224.888336
# 1     ZTF18abtnlik   643114394415015053  279.321654  49.148389   78.016574
# 2     ZTF19acjurot  1058126442015015014  320.853375 -17.720127   32.664194
# 3     ZTF20aanvpzo  1200441200215015003  224.375994   8.389928    6.711000
# 4     ZTF20aawxpru  1306411870015015009  322.840280   9.429956   62.842008
# ...            ...                  ...         ...        ...         ...
# 1790  ZTF18aarvhyg              unknown  256.956085  39.436829   63.570722
# 1791  ZTF18aatdcqo              unknown  126.808987  25.724485  198.001382
# 1792  ZTF18aatmzvi              unknown  284.974359  44.981763   75.135763
# 1793  ZTF18aatnjsg              unknown  250.386926  36.476340   59.024970
# 1794  ZTF18aaulvju              unknown  244.412102  30.524040   50.050632
#
#           gal_b    ecl_long    ecl_lat      magpsf    sigmapsf  ...  \
# 0    -43.699489   56.438373 -47.223415   19.800232    0.179855  ...
# 1     22.385199  289.985625  71.941418   20.333069    0.180506  ...
# 2    -41.349474  317.674423  -2.295138   18.519318    0.107349  ...
# 3     54.797328  219.201834  24.147229   19.587193    0.166170  ...
# 4    -29.301685  328.512798  22.789567   20.299837    0.208037  ...
# ...         ...         ...        ...         ...         ...  ...
# 1790  36.152051  248.282264  61.896232 -999.000000 -999.000000  ...
# 1791  31.559648  122.897930   6.391194 -999.000000 -999.000000  ...
# 1792  17.403278  297.861494  66.978337 -999.000000 -999.000000  ...
# 1793  40.942623  239.513923  57.857825 -999.000000 -999.000000  ...
# 1794  45.096258  233.931728  50.808172 -999.000000 -999.000000  ...
#
#         sgscore2    sgscore3   distpsnr1   distpsnr2   distpsnr3  ndethist  \
# 0       0.001250    0.500000    5.558571    6.079560    7.264775      12.0
# 1       0.994167    0.997250    5.262714    6.867275    9.061376     150.0
# 2       0.500000    0.000000    0.008522    0.558093    7.119209      10.0
# 3       0.500000    0.107167    8.462006    9.868366   10.590695      13.0
# 4       0.254470    0.140304    5.226012    5.712976    8.442719      43.0
# ...          ...         ...         ...         ...         ...       ...
# 1790 -999.000000 -999.000000 -999.000000 -999.000000 -999.000000    -999.0
# 1791 -999.000000 -999.000000 -999.000000 -999.000000 -999.000000    -999.0
# 1792 -999.000000 -999.000000 -999.000000 -999.000000 -999.000000    -999.0
# 1793 -999.000000 -999.000000 -999.000000 -999.000000 -999.000000    -999.0
# 1794 -999.000000 -999.000000 -999.000000 -999.000000 -999.000000    -999.0
#
#       ncovhist    chinr  sharpnr  non_detections
# 0        232.0    3.333    0.240           220.0
# 1        960.0    2.963    0.086           810.0
# 2        133.0    1.575    0.042           123.0
# 3        345.0    1.611    0.367           332.0
# 4        422.0    7.562    0.575           379.0
# ...        ...      ...      ...             ...
# 1790    -999.0 -999.000 -999.000          -999.0
# 1791    -999.0 -999.000 -999.000          -999.0
# 1792    -999.0 -999.000 -999.000          -999.0
# 1793    -999.0 -999.000 -999.000          -999.0
# 1794    -999.0 -999.000 -999.000          -999.0
#
# [50925 rows x 25 columns]

# %%
metadata.columns
# Out:
# Index(['oid', 'candid', 'ra', 'dec', 'gal_l', 'gal_b', 'ecl_long', 'ecl_lat',
#        'magpsf', 'sigmapsf', 'isdiffpos', 'diffmaglim', 'classtar', 'fwhm',
#        'sgscore1', 'sgscore2', 'sgscore3', 'distpsnr1', 'distpsnr2',
#        'distpsnr3', 'ndethist', 'ncovhist', 'chinr', 'sharpnr',
#        'non_detections'],
#       dtype='object')

# %%
clipping_rules = {
    'sgscore1': (-1, None),
    'distpsnr1': (-1, None),
    'sgscore2': (-1, None),
    'distpsnr2': (-1, None),
    'sgscore3': (-1, None),
    'distpsnr3': (-1, None),
    'fwhm': (None, 10),
    'ndethist': (None, 20),
    'ncovhist': (None, 3000),
    'chinr': (-1, 15),
    'sharpnr': (-1, 1.5),
    'non_detections': (None, 2000)
}

for feature, (min_val, max_val) in clipping_rules.items():
    if feature in metadata.columns:
        if min_val is not None:
            metadata[feature] = metadata[feature].clip(lower=min_val)
        if max_val is not None:
            metadata[feature] = metadata[feature].clip(upper=max_val)

# %%
metadata
# Out:
#                oid               candid          ra        dec       gal_l  \
# 0     ZTF21aaebkmj  1501128131215015004   65.163495 -26.636435  224.888336
# 1     ZTF18abtnlik   643114394415015053  279.321654  49.148389   78.016574
# 2     ZTF19acjurot  1058126442015015014  320.853375 -17.720127   32.664194
# 3     ZTF20aanvpzo  1200441200215015003  224.375994   8.389928    6.711000
# 4     ZTF20aawxpru  1306411870015015009  322.840280   9.429956   62.842008
# ...            ...                  ...         ...        ...         ...
# 1790  ZTF18aarvhyg              unknown  256.956085  39.436829   63.570722
# 1791  ZTF18aatdcqo              unknown  126.808987  25.724485  198.001382
# 1792  ZTF18aatmzvi              unknown  284.974359  44.981763   75.135763
# 1793  ZTF18aatnjsg              unknown  250.386926  36.476340   59.024970
# 1794  ZTF18aaulvju              unknown  244.412102  30.524040   50.050632
#
#           gal_b    ecl_long    ecl_lat      magpsf    sigmapsf  ...  sgscore2  \
# 0    -43.699489   56.438373 -47.223415   19.800232    0.179855  ...  0.001250
# 1     22.385199  289.985625  71.941418   20.333069    0.180506  ...  0.994167
# 2    -41.349474  317.674423  -2.295138   18.519318    0.107349  ...  0.500000
# 3     54.797328  219.201834  24.147229   19.587193    0.166170  ...  0.500000
# 4    -29.301685  328.512798  22.789567   20.299837    0.208037  ...  0.254470
# ...         ...         ...        ...         ...         ...  ...       ...
# 1790  36.152051  248.282264  61.896232 -999.000000 -999.000000  ... -1.000000
# 1791  31.559648  122.897930   6.391194 -999.000000 -999.000000  ... -1.000000
# 1792  17.403278  297.861494  66.978337 -999.000000 -999.000000  ... -1.000000
# 1793  40.942623  239.513923  57.857825 -999.000000 -999.000000  ... -1.000000
# 1794  45.096258  233.931728  50.808172 -999.000000 -999.000000  ... -1.000000
#
#       sgscore3  distpsnr1  distpsnr2  distpsnr3  ndethist  ncovhist  chinr  \
# 0     0.500000   5.558571   6.079560   7.264775      12.0     232.0  3.333
# 1     0.997250   5.262714   6.867275   9.061376      20.0     960.0  2.963
# 2     0.000000   0.008522   0.558093   7.119209      10.0     133.0  1.575
# 3     0.107167   8.462006   9.868366  10.590695      13.0     345.0  1.611
# 4     0.140304   5.226012   5.712976   8.442719      20.0     422.0  7.562
# ...        ...        ...        ...        ...       ...       ...    ...
# 1790 -1.000000  -1.000000  -1.000000  -1.000000    -999.0    -999.0 -1.000
# 1791 -1.000000  -1.000000  -1.000000  -1.000000    -999.0    -999.0 -1.000
# 1792 -1.000000  -1.000000  -1.000000  -1.000000    -999.0    -999.0 -1.000
# 1793 -1.000000  -1.000000  -1.000000  -1.000000    -999.0    -999.0 -1.000
# 1794 -1.000000  -1.000000  -1.000000  -1.000000    -999.0    -999.0 -1.000
#
#       sharpnr  non_detections
# 0       0.240           220.0
# 1       0.086           810.0
# 2       0.042           123.0
# 3       0.367           332.0
# 4       0.575           379.0
# ...       ...             ...
# 1790   -1.000          -999.0
# 1791   -1.000          -999.0
# 1792   -1.000          -999.0
# 1793   -1.000          -999.0
# 1794   -1.000          -999.0
#
# [50925 rows x 25 columns]

# %%
oids_train = normalized_ndarrays['oid_train']
oids_val = normalized_ndarrays['oid_val']
oids_test = normalized_ndarrays['oid_test']

print(oids_train.shape)
print(oids_val.shape)
print(oids_test.shape)
# Out:
# (29586,)
# (9862,)
# (9862,)

# %%
train_metadata = metadata.drop_duplicates(subset='oid', keep='first').set_index('oid').loc[oids_train]
val_metadata = metadata.drop_duplicates(subset='oid', keep='first').set_index('oid').loc[oids_val]
test_metadata = metadata.drop_duplicates(subset='oid', keep='first').set_index('oid').loc[oids_test]

print(train_metadata.shape)
print(val_metadata.shape)
print(test_metadata.shape)
# Out:
# (29586, 24)
# (9862, 24)
# (9862, 24)

# %%
features = metadata.columns.difference(['oid', 'candid'])

# 1. Calcular stats del set de entrenamiento
means = train_metadata[features].mean()
stds = train_metadata[features].std().replace(0, 1)

# 2. Aplicar normalización a todos los conjuntos
train_metadata[features] = (train_metadata[features] - means) / stds
val_metadata[features]   = (val_metadata[features]   - means) / stds
test_metadata[features]  = (test_metadata[features]  - means) / stds

# %%
type(means)
# Out:
# pandas.core.series.Series

# %%
print(means)
print(stds)
# Out:
# chinr               1.276762
# classtar          -15.992573
# dec                24.557728
# diffmaglim          2.940792
# distpsnr1           5.011400
# distpsnr2          11.236211
# distpsnr3          13.955814
# ecl_lat            24.089291
# ecl_long          165.049949
# fwhm              -14.508544
# gal_b              15.701868
# gal_l             141.581052
# isdiffpos         -16.392483
# magpsf              1.706330
# ncovhist          770.020550
# ndethist           -7.818360
# non_detections    645.999121
# ra                183.489901
# sgscore1            0.592215
# sgscore2            0.449422
# sgscore3            0.392349
# sharpnr            -0.036260
# sigmapsf          -16.736783
# dtype: float64
# chinr               1.474401
# classtar          128.886498
# dec                25.694754
# diffmaglim        131.370326
# distpsnr1           6.315172
# distpsnr2           7.227138
# distpsnr3           8.002099
# ecl_lat            29.776543
# ecl_long           98.112176
# fwhm              129.085305
# gal_b              37.355342
# gal_l              82.527217
# isdiffpos         128.836846
# magpsf            131.213323
# ncovhist          756.358443
# ndethist          130.265775
# non_detections    625.351586
# ra                 99.249450
# sgscore1            0.460625
# sgscore2            0.471171
# sgscore3            0.559422
# sharpnr             0.250471
# sigmapsf          128.788848
# dtype: float64

# %%
final_metadata = pd.concat([train_metadata, val_metadata, test_metadata])
final_metadata
# Out:
#                            candid        ra       dec     gal_l     gal_b  \
# oid
# ZTF20abgjnrb  1265389283815015021  1.310920 -0.484312 -0.998308 -0.967269
# ZTF19aalbuqo  1883492454315010007  0.597084  0.351684 -1.059043  0.834596
# ZTF18acpakyz   685364294215010170 -0.543578 -0.188053  0.776190  0.436578
# ZTF18abcglxf  1558425261015015021  0.792362 -0.077278 -1.164193  0.323012
# ZTF19aaujiwc   918195210315015002  0.349005 -0.623357  2.644108  1.178518
# ...                           ...       ...       ...       ...       ...
# ZTF19aatffoc   848288634115010027  0.456803  0.269942 -1.114171  1.145037
# ZTF19aaezvxh   757184913115015021 -0.865761 -0.549490  0.722905 -0.417529
# ZTF19aallcym   789263623215015004 -0.090305 -1.002436  1.532675  1.095510
# ZTF19aaqcnqz   832230852015015001 -0.028212 -0.503962  1.485903  1.472977
# ZTF20abjojwr  1280352293415015005  1.089797  1.466399 -0.581131  0.111963
#
#               ecl_long   ecl_lat    magpsf  sigmapsf  isdiffpos  ...  \
# oid                                                              ...
# ZTF20abgjnrb  1.579104  0.141624  0.139063  0.131236   0.134996  ...
# ZTF19aalbuqo  0.665017  0.982415  0.136807  0.131261   0.119473  ...
# ZTF18acpakyz -0.389591 -0.768763  0.116330  0.130636   0.119473  ...
# ZTF18abcglxf  0.963355  0.726663  0.104492  0.130052   0.134996  ...
# ZTF19aaujiwc  0.486579 -0.060765  0.131177  0.130847   0.134996  ...
# ...                ...       ...       ...       ...        ...  ...
# ZTF19aatffoc  0.500664  0.778638  0.135224  0.131184   0.119473  ...
# ZTF19aaezvxh -0.687189 -1.238888  0.134250  0.131160   0.134996  ...
# ZTF19aallcym  0.106027 -0.919005  0.131510  0.131180   0.134996  ...
# ZTF19aaqcnqz  0.111174 -0.442520  0.116711  0.130249   0.134996  ...
# ZTF20abjojwr  1.836685  1.869703  0.134011  0.131299   0.134996  ...
#
#               sgscore2  sgscore3  distpsnr1  distpsnr2  distpsnr3  ndethist  \
# oid
# ZTF20abgjnrb  0.886167  1.063793   0.304509  -0.287636  -0.171241  0.067695
# ZTF19aalbuqo -0.949066 -0.697623  -0.746667   0.674522   0.415380  0.213551
# ZTF18acpakyz  0.107345  0.192433  -0.751818  -1.316378  -1.016939  0.067695
# ZTF18abcglxf  0.107345  0.826644  -0.699784  -1.305779  -0.798103  0.213551
# ZTF19aaujiwc  0.107345  0.192433  -0.534337  -0.689719  -0.574778  0.213551
# ...                ...       ...        ...        ...        ...       ...
# ZTF19aatffoc  1.168532  1.049716  -0.752415   0.220251  -0.108684  0.067695
# ZTF19aaezvxh  0.920480  1.045992   0.294483  -0.094884  -0.365746  0.067695
# ZTF19aallcym  1.144655 -0.547510  -0.094001   0.187625   0.643407  0.067695
# ZTF19aaqcnqz  0.107345 -0.695388   1.269518   0.490674   0.920917  0.067695
# ZTF20abjojwr  0.583818  1.086212   0.738789   0.318404   0.293334  0.067695
#
#               ncovhist     chinr   sharpnr  non_detections
# oid
# ZTF20abgjnrb -0.347746 -0.196529 -0.302391       -0.223873
# ZTF19aalbuqo  2.948310 -0.462400  0.180698        2.165183
# ZTF18acpakyz -0.920226  2.980355  1.873507       -0.916283
# ZTF18abcglxf  1.459598 -0.712671  0.148759        0.778763
# ZTF19aaujiwc -0.875274  4.247988  2.029214       -0.901891
# ...                ...       ...       ...             ...
# ZTF19aatffoc -1.015419  1.123329  1.182809       -1.031418
# ZTF19aaezvxh -0.339813 -0.190425 -2.466312       -0.214278
# ZTF19aallcym -0.987654 -0.115140 -1.611922       -0.997837
# ZTF19aaqcnqz -0.860730 -0.417636 -0.442128       -0.844324
# ZTF20abjojwr  1.220294 -0.562779 -0.030903        1.672660
#
# [49310 rows x 24 columns]

# %%
final_metadata.index.nunique()
# Out:
# 49310

# %%
final_metadata.to_parquet('data/clipped_normalized_metadata.parquet')

# %%
metadata_hasavro = pd.read_parquet('data/full_stamp_classifier_metadata_hasavro.parquet')
metadata_hasavro

# %%
metadata_hasavro['non_detections'] = metadata_hasavro['ncovhist'] - metadata_hasavro['ndethist']
metadata_hasavro = metadata_hasavro.fillna(-999)
clipping_rules = {
    'sgscore1': (-1, None),
    'distpsnr1': (-1, None),
    'sgscore2': (-1, None),
    'distpsnr2': (-1, None),
    'sgscore3': (-1, None),
    'distpsnr3': (-1, None),
    'fwhm': (None, 10),
    'ndethist': (None, 20),
    'ncovhist': (None, 3000),
    'chinr': (-1, 15),
    'sharpnr': (-1, 1.5),
    'non_detections': (None, 2000)
}
for feature, (min_val, max_val) in clipping_rules.items():
    if feature in metadata_hasavro.columns:
        if min_val is not None:
            metadata_hasavro[feature] = metadata_hasavro[feature].clip(lower=min_val)
        if max_val is not None:
            metadata_hasavro[feature] = metadata_hasavro[feature].clip(upper=max_val)

oids_train = normalized_ndarrays['oid_train']
oids_val = normalized_ndarrays['oid_val']
oids_test = normalized_ndarrays['oid_test']

print(oids_train.shape)
print(oids_val.shape)
print(oids_test.shape)

train_metadata_hasavro = metadata_hasavro.drop_duplicates(subset='oid', keep='first').set_index('oid').loc[oids_train]
val_metadata_hasavro = metadata_hasavro.drop_duplicates(subset='oid', keep='first').set_index('oid').loc[oids_val]
test_metadata_hasavro = metadata_hasavro.drop_duplicates(subset='oid', keep='first').set_index('oid').loc[oids_test]

print(train_metadata_hasavro.shape)
print(val_metadata_hasavro.shape)
print(test_metadata_hasavro.shape)

features = metadata_hasavro.columns.difference(['oid', 'candid'])

# 1. Calcular stats del set de entrenamiento
means = train_metadata_hasavro[features].mean()
stds = train_metadata_hasavro[features].std().replace(0, 1)

# 2. Aplicar normalización a todos los conjuntos
train_metadata_hasavro[features] = (train_metadata_hasavro[features] - means) / stds
val_metadata_hasavro[features]   = (val_metadata_hasavro[features]   - means) / stds
test_metadata_hasavro[features]  = (test_metadata_hasavro[features]  - means) / stds

final_metadata_hasavro = pd.concat([train_metadata_hasavro, val_metadata_hasavro, test_metadata_hasavro])
final_metadata_hasavro.to_parquet('data/clipped_normalized_metadata_hasavro.parquet')
