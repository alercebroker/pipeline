# %%
import pandas as pd

# %%
consolidated_features = pd.read_parquet('data_241015_ao_shorten_features/consolidated_features.parquet')
consolidated_features
# Out:
#               g-r_mean_g,r  g-r_max_g,r  g-r_mean_corr_g,r  g-r_max_corr_g,r
# oid
# ZTF17aaaocpq      0.648299     0.301030           0.794814          0.579872  \
# ZTF17aaazbbb      0.709376     0.930821           0.401579          0.520716
# ZTF17aaazlzl      0.654706     2.438853           0.629044          1.160559
# ZTF17aaazuft      0.702101     0.723674           0.601958          0.643968
# ZTF17aabhjci      0.370595     0.079380           0.695512          0.437549
# ...                    ...          ...                ...               ...
# ZTF23aamaycf      1.014502     1.476580           2.118903          2.100804
# ZTF23aaoscaj           NaN          NaN                NaN               NaN
# ZTF23aappeda      0.919707     0.822715           1.379350          1.328777
# ZTF23aazoggh      1.675847     1.544912           1.460800          1.462652
# ZTF23abdyjve           NaN          NaN                NaN               NaN
#
# ...

# %%
# Assuming your DataFrame is named 'df'
nan_columns = [col for col in consolidated_features.columns if '_nan' in col]

# Display the columns
print(nan_columns)
# Out:
# ['W1-W2_nan', 'W2-W3_nan', 'W3-W4_nan', 'g-W1_nan', 'r-W1_nan', 'g-W2_nan', 'r-W2_nan', 'g-W3_nan', 'r-W3_nan', 'g-W4_nan', 'r-W4_nan', 'sgscore1_nan', 'distpsnr1_nan', 'ps_g-r_nan', 'ps_r-i_nan', 'ps_i-z_nan', 'Timespan_nan', 'Coordinate_x_nan', 'Coordinate_y_nan', 'Coordinate_z_nan']

# %%
for col in consolidated_features.columns:
    print(col)
# Out:
# g-r_mean_g,r
# g-r_max_g,r
# g-r_mean_corr_g,r
# g-r_max_corr_g,r
# W1-W2_nan
# W2-W3_nan
# W3-W4_nan
# g-W1_nan
# r-W1_nan
# g-W2_nan
# r-W2_nan
# g-W3_nan
# r-W3_nan
# g-W4_nan
# r-W4_nan
# sgscore1_nan
# distpsnr1_nan
# ps_g-r_nan
# ps_r-i_nan
# ps_i-z_nan
# MHPS_ratio_g
# MHPS_low_g
# MHPS_high_g
# MHPS_non_zero_g
# MHPS_PN_flag_g
# MHPS_ratio_r
# MHPS_low_r
# MHPS_high_r
# MHPS_non_zero_r
# MHPS_PN_flag_r
# MHPS_ratio_365_30_g
# MHPS_low_365_g
# MHPS_high_30_g
# MHPS_ratio_365_30_r
# MHPS_low_365_r
# MHPS_high_30_r
# GP_DRW_sigma_g
# GP_DRW_tau_g
# GP_DRW_sigma_r
# GP_DRW_tau_r
# Multiband_period_g,r
# PPE_g,r
# Period_band_g
# delta_period_g
# Period_band_r
# delta_period_r
# Power_rate_1_4_g,r
# Power_rate_1_3_g,r
# Power_rate_1_2_g,r
# Power_rate_2_g,r
# Power_rate_3_g,r
# Power_rate_4_g,r
# Psi_CS_g
# Psi_eta_g
# Psi_CS_r
# Psi_eta_r
# Harmonics_mse_g
# Harmonics_chi_g
# Harmonics_mag_1_g
# Harmonics_mag_2_g
# Harmonics_phase_2_g
# Harmonics_mag_3_g
# Harmonics_phase_3_g
# ...
