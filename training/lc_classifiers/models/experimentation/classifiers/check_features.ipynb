# %%
import pandas as pd

# %%
import pyarrow.parquet as pq

parquet_file = pq.ParquetFile("consolidated_features_16.parquet")
print(parquet_file.metadata)
# Out:
# ...
#   created_by: parquet-cpp-arrow version 16.1.0
#   num_columns: 211
#   num_rows: 319520
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 111091

# %%
print(parquet_file.metadata.num_rows)
print(parquet_file.metadata.format_version)
print(parquet_file.metadata.schema)
# Out:
# 319520
# 2.6
# ...
# required group field_id=-1 schema {
#   optional double field_id=-1 g-r_mean_g,r;
#   optional double field_id=-1 g-r_max_g,r;
#   optional double field_id=-1 g-r_mean_corr_g,r;
#   optional double field_id=-1 g-r_max_corr_g,r;
#   optional binary field_id=-1 W1-W2_nan (String);
#   optional binary field_id=-1 W2-W3_nan (String);
#   optional binary field_id=-1 W3-W4_nan (String);
#   optional binary field_id=-1 g-W1_nan (String);
#   optional binary field_id=-1 r-W1_nan (String);
#   optional binary field_id=-1 g-W2_nan (String);
#   optional binary field_id=-1 r-W2_nan (String);
#   optional binary field_id=-1 g-W3_nan (String);
#   optional binary field_id=-1 r-W3_nan (String);
#   optional binary field_id=-1 g-W4_nan (String);
#   optional binary field_id=-1 r-W4_nan (String);
#   optional double field_id=-1 sgscore1_nan;
#   optional double field_id=-1 distpsnr1_nan;
#   optional double field_id=-1 ps_g-r_nan;
#   optional double field_id=-1 ps_r-i_nan;
# ...

# %%
consolidated_features = pd.read_parquet('consolidated_features_16.parquet')
consolidated_features
# Out:
#               g-r_mean_g,r  g-r_max_g,r  g-r_mean_corr_g,r  g-r_max_corr_g,r  \
# oid
# ZTF17aaaocpq      0.674468     0.301030           0.795315          0.579872
# ZTF17aaazbbb      0.709376     0.930821           0.401579          0.520716
# ZTF17aaazlzl      0.654706     2.438853           0.629044          1.160559
# ZTF17aaazuft      0.702101     0.723674           0.601958          0.643968
# ZTF17aabhjci      0.365223     0.079380           0.695261          0.437549
# ...                    ...          ...                ...               ...
# ZTF23aamaycf      1.014502     1.476580           2.118903          2.100804
# ZTF23aaoscaj           NaN          NaN                NaN               NaN
# ZTF23aappeda      0.919707     0.822715           1.379350          1.328777
# ZTF23aazoggh           NaN          NaN                NaN               NaN
# ZTF23abdyjve           NaN          NaN                NaN               NaN
#
# ...

# %%
consolidated_features = pd.read_parquet('data_241209_ndetge8_ao_shorten_features/consolidated_features.parquet')
consolidated_features
# Out:
#               g-r_mean_g,r  g-r_max_g,r  g-r_mean_corr_g,r  g-r_max_corr_g,r  \
# oid
# ZTF17aaaocpq      0.674468     0.301030           0.795315          0.579872
# ZTF17aaazbbb      0.709376     0.930821           0.401579          0.520716
# ZTF17aaazlzl      0.654706     2.438853           0.629044          1.160559
# ZTF17aaazuft      0.702101     0.723674           0.601958          0.643968
# ZTF17aabhjci      0.365223     0.079380           0.695261          0.437549
# ...                    ...          ...                ...               ...
# ZTF23aamaycf      1.014502     1.476580           2.118903          2.100804
# ZTF23aaoscaj           NaN          NaN                NaN               NaN
# ZTF23aappeda      0.919707     0.822715           1.379350          1.328777
# ZTF23aazoggh           NaN          NaN                NaN               NaN
# ZTF23abdyjve           NaN          NaN                NaN               NaN
#
# ...

# %%
consolidated_features.dtypes
# Out:
# g-r_mean_g,r         float64
# g-r_max_g,r          float64
# g-r_mean_corr_g,r    float64
# g-r_max_corr_g,r     float64
# W1-W2_nan             object
#                       ...
# Timespan_nan         float64
# Coordinate_x_nan     float64
# Coordinate_y_nan     float64
# Coordinate_z_nan     float64
# shorten               object
# Length: 210, dtype: object

# %%
# Assuming your DataFrame is named 'df'
nan_columns = [col for col in consolidated_features.columns if '_nan' in col]

# Display the columns
print(nan_columns)
# Out:
# ['W1-W2_nan', 'W2-W3_nan', 'W3-W4_nan', 'g-W1_nan', 'r-W1_nan', 'g-W2_nan', 'r-W2_nan', 'g-W3_nan', 'r-W3_nan', 'g-W4_nan', 'r-W4_nan', 'sgscore1_nan', 'distpsnr1_nan', 'ps_g-r_nan', 'ps_r-i_nan', 'ps_i-z_nan', 'Timespan_nan', 'Coordinate_x_nan', 'Coordinate_y_nan', 'Coordinate_z_nan']

# %%
for col in consolidated_features.columns:
    print(col)
# Out:
# g-r_mean_g,r
# g-r_max_g,r
# g-r_mean_corr_g,r
# g-r_max_corr_g,r
# W1-W2_nan
# W2-W3_nan
# W3-W4_nan
# g-W1_nan
# r-W1_nan
# g-W2_nan
# r-W2_nan
# g-W3_nan
# r-W3_nan
# g-W4_nan
# r-W4_nan
# sgscore1_nan
# distpsnr1_nan
# ps_g-r_nan
# ps_r-i_nan
# ps_i-z_nan
# MHPS_ratio_g
# MHPS_low_g
# MHPS_high_g
# MHPS_non_zero_g
# MHPS_PN_flag_g
# MHPS_ratio_r
# MHPS_low_r
# MHPS_high_r
# MHPS_non_zero_r
# MHPS_PN_flag_r
# MHPS_ratio_365_30_g
# MHPS_low_365_g
# MHPS_high_30_g
# MHPS_ratio_365_30_r
# MHPS_low_365_r
# MHPS_high_30_r
# GP_DRW_sigma_g
# GP_DRW_tau_g
# GP_DRW_sigma_r
# GP_DRW_tau_r
# Multiband_period_g,r
# PPE_g,r
# Period_band_g
# delta_period_g
# Period_band_r
# delta_period_r
# Power_rate_1_4_g,r
# Power_rate_1_3_g,r
# Power_rate_1_2_g,r
# Power_rate_2_g,r
# Power_rate_3_g,r
# Power_rate_4_g,r
# Psi_CS_g
# Psi_eta_g
# Psi_CS_r
# Psi_eta_r
# Harmonics_mse_g
# Harmonics_chi_g
# Harmonics_mag_1_g
# Harmonics_mag_2_g
# Harmonics_phase_2_g
# Harmonics_mag_3_g
# Harmonics_phase_3_g
# ...
