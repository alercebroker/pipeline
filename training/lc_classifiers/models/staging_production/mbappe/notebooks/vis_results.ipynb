# %%
# %cd ../
# Out:
# /home/dmoreno/pipeline_v4_final/pipeline/training/classifiers/models/staging_production/mbappe

# %%
import pandas as pd

# %%
order_classes = [
        "SNIa", "SNIbc", "SNIIb", "SNII", "SNIIn", "SLSN", 
        "TDE", "Microlensing", "QSO", "AGN", "Blazar", 
        "YSO", "CV/Nova", "LPV", "EA", "EB/EW", 
        "Periodic-Other", "RSCVn", "CEP", "RRLab", "RRLc", "DSCT"
    ]

path_results = './results/mbappe_0.3.5/predictions_test.parquet'
#path_results = './results/detections_and_ff/predictions_test.parquet'
predictions = pd.read_parquet(path_results)
predictions
# Out:
#                    AGN         EB/EW        Blazar           CEP  \
# oid
# ZTF17aaaocpq  0.929438  6.551693e-07  5.479553e-02  1.881386e-04
# ZTF17aaazlzl  0.958572  1.351267e-06  3.413444e-03  1.228938e-06
# ZTF18aaaokus  0.986684  2.326582e-05  1.121472e-02  1.931202e-05
# ZTF18aablatc  0.884949  3.357577e-06  2.734758e-03  2.838087e-07
# ZTF18aacglia  0.954263  1.691873e-07  1.278898e-03  2.801759e-07
# ...                ...           ...           ...           ...
# ZTF22aaaftbh  0.000011  9.971908e-06  6.728349e-08  1.745119e-02
# ZTF22aafvuwd  0.000004  1.713782e-05  1.326784e-07  2.011231e-02
# ZTF22abuluix  0.010215  7.677017e-06  6.473998e-01  1.020764e-04
# ZTF23aabvglf  0.000069  7.652389e-04  1.697501e-06  1.266383e-03
# ZTF23aazoggh  0.001536  5.131809e-03  4.727713e-04  5.821931e-03
#
#                        LPV       CV/Nova  Periodic-Other  Microlensing  \
# oid
# ZTF17aaaocpq  2.073621e-03  7.027530e-06    1.271968e-07  4.059483e-13
# ZTF17aaazlzl  9.090621e-06  2.442416e-04    1.372999e-08  4.173237e-13
# ZTF18aaaokus  6.007269e-04  3.508283e-05    2.152004e-07  1.210941e-12
# ZTF18aablatc  3.258760e-07  2.543272e-07    8.874098e-06  3.567582e-11
# ZTF18aacglia  5.776111e-07  2.665965e-06    1.008065e-06  3.358395e-13
# ...                    ...           ...             ...           ...
# ZTF22aaaftbh  5.462072e-03  9.849953e-06    1.273062e-04  4.670166e-13
# ZTF22aafvuwd  3.108441e-04  4.574887e-05    2.875655e-01  1.090473e-11
# ZTF22abuluix  2.054089e-02  7.768045e-04    2.744101e-04  4.576917e-10
# ZTF23aabvglf  9.879848e-04  2.045579e-03    1.076288e-01  4.011945e-10
# ZTF23aazoggh  4.790775e-02  3.983181e-02    2.767760e-06  2.414617e-08
#
#                        QSO          DSCT  ...         RSCVn      RRLc  \
# oid                                       ...
# ZTF17aaaocpq  7.309800e-04  2.015011e-07  ...  1.265545e-05  0.000017
# ZTF17aaazlzl  7.582024e-05  9.392326e-07  ...  1.015910e-07  0.000007
# ZTF18aaaokus  7.458775e-05  5.661748e-07  ...  1.043364e-04  0.000009
# ZTF18aablatc  1.122948e-01  3.750644e-08  ...  2.619734e-06  0.000005
# ZTF18aacglia  4.444023e-02  6.166068e-08  ...  5.886826e-07  0.000001
# ...                    ...           ...  ...           ...       ...
# ZTF22aaaftbh  1.561594e-06  8.870890e-05  ...  6.136004e-02  0.000012
# ZTF22aafvuwd  1.684081e-07  3.549546e-05  ...  1.170240e-01  0.000026
# ZTF22abuluix  6.090795e-04  9.504441e-05  ...  1.834679e-01  0.000102
# ZTF23aabvglf  4.033629e-06  7.136284e-03  ...  1.593845e-02  0.000035
# ZTF23aazoggh  5.232532e-04  1.715526e-03  ...  6.541730e-02  0.000043
#
#                       SLSN          SNII         SNIIb         SNIIn  \
# oid
# ZTF17aaaocpq  7.051904e-06  2.133231e-07  8.604305e-09  2.424417e-10
# ZTF17aaazlzl  3.611451e-09  4.509707e-03  1.411718e-07  2.604571e-08
# ZTF18aaaokus  3.137562e-09  1.973529e-04  3.470287e-06  7.415272e-08
# ZTF18aablatc  2.040018e-08  3.979651e-09  9.908281e-10  2.706558e-09
# ZTF18aacglia  8.547102e-10  1.881367e-08  3.665330e-07  1.617944e-12
# ...                    ...           ...           ...           ...
# ZTF22aaaftbh  3.345962e-13  4.278869e-12  1.736949e-14  7.040833e-11
# ZTF22aafvuwd  8.790012e-13  1.318818e-11  9.887301e-18  2.606190e-09
# ZTF22abuluix  6.564922e-08  5.274824e-07  3.818013e-14  2.573651e-09
# ZTF23aabvglf  1.080433e-09  4.843937e-10  4.846095e-12  1.161408e-06
# ZTF23aazoggh  5.717239e-04  3.836051e-05  1.721291e-14  7.880084e-09
#
#                       SNIa         SNIbc           TDE           YSO
# oid
# ZTF17aaaocpq  2.781157e-06  3.230248e-11  1.433406e-13  1.272511e-02
# ZTF17aaazlzl  3.290914e-02  1.108798e-08  4.115660e-11  1.777453e-04
# ZTF18aaaokus  6.614139e-04  6.914408e-11  4.603852e-09  3.501441e-04
# ZTF18aablatc  3.843169e-07  2.596559e-10  2.858970e-11  6.769399e-08
# ZTF18aacglia  2.443125e-06  1.908200e-10  3.672092e-15  7.652540e-06
# ...                    ...           ...           ...           ...
# ZTF22aaaftbh  2.417547e-10  4.627168e-12  8.706863e-14  9.154606e-01
# ZTF22aafvuwd  2.983834e-11  6.267723e-12  6.809852e-14  5.748416e-01
# ZTF22abuluix  2.468361e-07  8.326188e-12  4.141891e-11  1.363354e-01
# ZTF23aabvglf  4.180854e-07  2.401562e-06  3.002310e-10  8.639641e-01
# ZTF23aazoggh  2.497573e-05  3.142560e-05  4.041918e-12  8.183794e-01
#
# [7988 rows x 22 columns]

# %%
y_pred_test = predictions.idxmax(axis=1).values
y_pred_test
# Out:
# array(['AGN', 'AGN', 'AGN', ..., 'Blazar', 'YSO', 'YSO'], dtype=object)

# %%
ROOT = "../../../data_acquisition/ztf_forced_photometry"
objects_partitions = pd.read_parquet(f'{ROOT}/preprocessed/partitions/241209/partitions.parquet')
obj_label = objects_partitions[objects_partitions['partition'] == 'test'].set_index('oid')
obj_label = obj_label.reindex(predictions.index)
y_real_test = obj_label['class_name'].values
y_real_test
# Out:
# array(['AGN', 'AGN', 'AGN', ..., 'YSO', 'YSO', 'YSO'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

fs = 12

cm = confusion_matrix(y_true=y_real_test, y_pred=y_pred_test, labels=order_classes, normalize='true')

cmap = plt.cm.Blues
fig, ax = plt.subplots(figsize=(11, 11)) #, dpi=110)
im = ax.imshow(np.around(cm, decimals=2), interpolation='nearest', cmap=cmap)

# color map
new_color = cmap(1.0) 

# Añadiendo manualmente las anotaciones con la media y desviación estándar
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        if cm[i, j] >= 0.005:
            #print(cm[i, j])
            text = f'{np.around(cm[i, j], decimals=2)}'
            color = "white" if cm[i, j] > 0.5 else new_color  # Blanco para la diagonal, tono de azul para otras celdas
            ax.text(j, i, text, ha="center", va="center", color=color, fontsize=fs)
        else:
            text = f'{np.around(cm[i, j], decimals=2)}'
            color = "white" if cm[i, j] > 0.5 else new_color  # Blanco para la diagonal, tono de azul para otras celdas
            ax.text(j, i, text, ha="center", va="center", color=color, fontsize=fs)

# Ajustes finales y mostrar la gráfica
ax.tick_params(axis='both', which='major', labelsize=12)
ax.set_xticks(np.arange(len(order_classes)))
ax.set_yticks(np.arange(len(order_classes)))
ax.set_xticklabels(order_classes)
ax.set_yticklabels(order_classes)
plt.setp(ax.get_xticklabels(), rotation=90, ha="right", rotation_mode="anchor")

title = '/'.join(path_results.split('/')[1:-1])
ax.set_title(title, fontsize=16, pad=13)
ax.set_xlabel('Predicted label', fontsize=16, labelpad=13)  # Label del eje x
ax.set_ylabel('True label', fontsize=16, labelpad=13)        # Label del eje y

ax.xaxis.label.set_size(16)
ax.yaxis.label.set_size(16)
ax.xaxis.labelpad = 13
ax.yaxis.labelpad = 13

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

f1 = f1_score(y_real_test, y_pred_test, average='macro')
f1
# Out:
# np.float64(0.728612834860268)

# %%
report = classification_report(y_real_test, y_pred_test, output_dict=False, digits=4)
print(report)
# Out:
#                 precision    recall  f1-score   support
#
#            AGN     0.8170    0.8436    0.8301       582
#         Blazar     0.8603    0.8571    0.8587       273
#            CEP     0.9180    0.8864    0.9019       581
#        CV/Nova     0.8764    0.9512    0.9123       328
#           DSCT     0.9154    0.9270    0.9211       315
#             EA     0.8657    0.9016    0.8832       579
#          EB/EW     0.9189    0.8109    0.8615       587
#            LPV     0.9688    0.9522    0.9604       586
#   Microlensing     1.0000    0.5714    0.7273         7
# Periodic-Other     0.7368    0.6667    0.7000       252
#            QSO     0.8777    0.8356    0.8561       584
#          RRLab     0.9483    0.9354    0.9418       588
#           RRLc     0.9068    0.9114    0.9091       587
#          RSCVn     0.8157    0.9049    0.8580       494
#           SLSN     0.5385    0.3415    0.4179        41
#           SNII     0.7220    0.4884    0.5827       303
#          SNIIb     0.5000    0.0417    0.0769        24
#          SNIIn     0.2979    0.2373    0.2642        59
#           SNIa     0.6869    0.9288    0.7898       548
#          SNIbc     0.3276    0.1881    0.2390       101
#            TDE     0.7143    0.5882    0.6452        17
#            YSO     0.8851    0.9348    0.9093       552
#
#       accuracy                         0.8542      7988
#      macro avg     0.7772    0.7138    0.7294      7988
#   weighted avg     0.8521    0.8542    0.8493      7988

# %%
import scipy.stats as stats

# %%
mean1, sem1 = 73.0, 3.0  # ATAT (LC)
mean2, sem2 = 76.0, 1.1  # SwinV2 Overlay

# Supongamos un tamaño de muestra suficientemente grande (n1, n2 desconocidos)
# Si los errores estándar son SEM = std / sqrt(n), podemos estimar n
n1 = (1 / sem1) ** 2  
n2 = (1 / sem2) ** 2  

# Calcular el estadístico t de Welch
t_stat = (mean1 - mean2) / np.sqrt((sem1 ** 2) + (sem2 ** 2))

# Grados de libertad aproximados de Welch-Satterthwaite
df = ((sem1 ** 2 + sem2 ** 2) ** 2) / (((sem1 ** 2) ** 2 / (n1 - 1)) + ((sem2 ** 2) ** 2 / (n2 - 1)))

# Calcular el p-valor (bilateral)
p_value = stats.t.sf(np.abs(t_stat), df) * 2

t_stat, df, p_value
# Out:
# (-0.9388763158866086, -1.0470374445225281, nan)
