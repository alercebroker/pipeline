# %% [markdown]
# # Confusion matrices

# %%
import os
import json 
import torch

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
model_dir = "models/hrf_classifier_20241120-115822"
predictions_filename = os.path.join(model_dir, "predictions.parquet")
predictions = pd.read_parquet(predictions_filename)
predictions
# Out:
#                        AGN    Blazar       CEP   CV/Nova      DSCT        EA  \
# index
# aid_ZTF17aaaocpq  0.274019  0.323965  0.008282  0.031802  0.000200  0.001479
# aid_ZTF17aaazbbb  0.629874  0.185243  0.001720  0.015746  0.000444  0.001086
# aid_ZTF17aaazlzl  0.408327  0.172802  0.004067  0.028232  0.001411  0.010718
# aid_ZTF17aaazuft  0.539812  0.193079  0.000763  0.004397  0.000230  0.000342
# aid_ZTF17aabhjci  0.260460  0.237665  0.019066  0.071313  0.000772  0.002793
# ...                    ...       ...       ...       ...       ...       ...
# aid_ZTF23aamaycf  0.084641  0.066134  0.013404  0.004160  0.000068  0.002840
# aid_ZTF23aaoscaj  0.036648  0.087262  0.045043  0.050203  0.014285  0.050833
# aid_ZTF23aappeda  0.013489  0.020425  0.051481  0.083976  0.008262  0.122116
# aid_ZTF23aazoggh  0.013716  0.031059  0.031766  0.089585  0.046332  0.048265
# aid_ZTF23abdyjve  0.038804  0.118179  0.014074  0.025008  0.001487  0.004085
#
#                      EB/EW       LPV  Microlensing  Periodic-Other  ...  \
# index                                                               ...
# aid_ZTF17aaaocpq  0.001386  0.039735      0.005580        0.002421  ...
# aid_ZTF17aaazbbb  0.000787  0.002478      0.000000        0.001524  ...
# aid_ZTF17aaazlzl  0.004368  0.006268      0.006507        0.006418  ...
# aid_ZTF17aaazuft  0.000220  0.003231      0.002192        0.001251  ...
# aid_ZTF17aabhjci  0.002440  0.009558      0.011998        0.003923  ...
# ...                    ...       ...           ...             ...  ...
# aid_ZTF23aamaycf  0.000685  0.019891      0.007628        0.001633  ...
# aid_ZTF23aaoscaj  0.026705  0.046977      0.126285        0.046988  ...
# aid_ZTF23aappeda  0.059358  0.012554      0.180265        0.026806  ...
# aid_ZTF23aazoggh  0.038729  0.013705      0.059407        0.106097  ...
# aid_ZTF23abdyjve  0.002749  0.113788      0.058715        0.009692  ...
#
#                      RSCVn      SLSN      SNII     SNIIb     SNIIn      SNIa  \
# index
# aid_ZTF17aaaocpq  0.004218  0.001649  0.001029  0.000231  0.002013  0.000731
# aid_ZTF17aaazbbb  0.004451  0.000865  0.000776  0.000451  0.001346  0.000563
# aid_ZTF17aaazlzl  0.007182  0.012353  0.022126  0.013199  0.028323  0.028211
# aid_ZTF17aaazuft  0.001155  0.001676  0.002415  0.001360  0.004359  0.003671
# aid_ZTF17aabhjci  0.009729  0.016334  0.020237  0.012147  0.044138  0.026238
# ...                    ...       ...       ...       ...       ...       ...
# aid_ZTF23aamaycf  0.007985  0.000499  0.000885  0.000295  0.000910  0.001292
# aid_ZTF23aaoscaj  0.055265  0.039126  0.015003  0.004889  0.022219  0.016454
# aid_ZTF23aappeda  0.033176  0.013771  0.008689  0.004237  0.012859  0.005574
# aid_ZTF23aazoggh  0.110053  0.009523  0.009256  0.005107  0.009795  0.009538
# aid_ZTF23abdyjve  0.004632  0.007812  0.001861  0.000577  0.003529  0.001904
#
#                      SNIbc       TDE       YSO  shorten
# index
# aid_ZTF17aaaocpq  0.000421  0.000936  0.231688     1024
# aid_ZTF17aaazbbb  0.000462  0.000823  0.092441     1024
# aid_ZTF17aaazlzl  0.021079  0.019514  0.157944     1024
# aid_ZTF17aaazuft  0.002460  0.001648  0.145894     1024
# aid_ZTF17aabhjci  0.015662  0.053918  0.119287     1024
# ...                    ...       ...       ...      ...
# aid_ZTF23aamaycf  0.000806  0.000524  0.758198     None
# aid_ZTF23aaoscaj  0.007513  0.029824  0.235021     None
# aid_ZTF23aappeda  0.009469  0.012581  0.259119     None
# aid_ZTF23aazoggh  0.009527  0.007924  0.300741     None
# aid_ZTF23abdyjve  0.002140  0.003580  0.483174     None
#
# [333496 rows x 23 columns]

# %%
predictions.index.nunique()
# Out:
# 41687

# %%
time_to_eval = 2048

order_classes = ['SNIa', # yes
                 'SNIbc', # yes
                 'SNIIb', # yes
                 'SNII', # yes
                 'SNIIn', # yes
                 'SLSN', # yes
                 'TDE', # yes
                 'Microlensing', # yes
                 'QSO', 
                 'AGN', # yes
                 'Blazar', 
                 'YSO', 
                 'CV/Nova', 
                 'LPV', 
                 'EA', 
                 'EB/EW', # yes
                 'Periodic-Other', 
                 'RSCVn', 
                 'CEP', 
                 'RRLab', 
                 'RRLc', 
                 'DSCT']

# %%
len(order_classes)
# Out:
# 22

# %%
objects_partitions = pd.read_parquet('../../data_acquisition/ztf_forced_fotometry/partitions/241119/partitions.parquet')
obj_label = objects_partitions[objects_partitions['partition'] == 'test']
y_real_test = obj_label['alerceclass'].values
obj_label = ['aid_{}'.format(x) for x in obj_label['oid'].values]
obj_label
# Out:
# ['aid_ZTF18abnukht',
#  'aid_ZTF17aabxfzy',
#  'aid_ZTF18aazwmdx',
#  'aid_ZTF19aclfauc',
#  'aid_ZTF18aaodyyn',
#  'aid_ZTF17aabgoup',
#  'aid_ZTF18aawvlsj',
#  'aid_ZTF19abqanpy',
#  'aid_ZTF18abbulky',
#  'aid_ZTF19acyxuwh',
#  'aid_ZTF21achakto',
#  'aid_ZTF21acbqhoo',
#  'aid_ZTF20aaybvnb',
#  'aid_ZTF21aawztrg',
#  'aid_ZTF18achdntb',
#  'aid_ZTF18aaptcwa',
#  'aid_ZTF17aaafieu',
#  'aid_ZTF19aassknd',
#  'aid_ZTF17aaaeayf',
#  'aid_ZTF17aaasjea',
#  'aid_ZTF18aabhztc',
#  'aid_ZTF21accibae',
#  'aid_ZTF19aaaonud',
#  'aid_ZTF18achyqcq',
#  'aid_ZTF18abnttfy',
#  'aid_ZTF21aagkzve',
#  'aid_ZTF17aabusvp',
#  'aid_ZTF17aaahfho',
#  'aid_ZTF18abboazo',
#  'aid_ZTF20abegate',
#  'aid_ZTF18aclceyr',
#  'aid_ZTF18abbwwfs',
#  'aid_ZTF18abfzzul',
#  'aid_ZTF18aamhoda',
#  'aid_ZTF19acbtljt',
#  'aid_ZTF19aauojfb',
#  'aid_ZTF22abunqtv',
#  'aid_ZTF23abavrya',
#  'aid_ZTF18aaypawy',
#  'aid_ZTF21aaesdgz',
#  'aid_ZTF20aaofywo',
#  'aid_ZTF23aasrcyv',
#  'aid_ZTF20abmljfh',
#  'aid_ZTF18aaveqks',
#  'aid_ZTF19aazljri',
#  'aid_ZTF17aaainmx',
#  'aid_ZTF19aaakulz',
#  'aid_ZTF19aadotfg',
#  'aid_ZTF18aagxrle',
#  'aid_ZTF20aciuucu',
#  'aid_ZTF22aaanfjh',
#  'aid_ZTF19acxozhr',
#  'aid_ZTF18aazstcv',
#  'aid_ZTF18acsxflq',
#  'aid_ZTF19aaynrzv',
#  'aid_ZTF20abxawtg',
#  'aid_ZTF18abrntto',
#  'aid_ZTF18accvfbv',
#  'aid_ZTF17aaaocpq',
#  'aid_ZTF18abxdqpp',
#  'aid_ZTF18abjyrjv',
#  'aid_ZTF18adqkwtb',
#  'aid_ZTF18abchjdx',
#  'aid_ZTF18abuykiu',
#  'aid_ZTF18aatjlte',
#  'aid_ZTF20aabcjoq',
#  'aid_ZTF19aayumur',
#  'aid_ZTF18abmoqyf',
#  'aid_ZTF22aavdiim',
#  'aid_ZTF17aaaaaej',
#  'aid_ZTF18aaaeefe',
#  'aid_ZTF20acxdlcd',
#  'aid_ZTF18aagrjqm',
#  'aid_ZTF18abaamta',
#  'aid_ZTF21aaloxey',
#  'aid_ZTF22acahcqc',
#  'aid_ZTF18abebalg',
#  'aid_ZTF20acuaqlf',
#  'aid_ZTF18achkcym',
#  'aid_ZTF18acmrnrb',
#  'aid_ZTF17aadjzhj',
#  'aid_ZTF20acjbhhp',
#  'aid_ZTF18acwyqeg',
#  'aid_ZTF18acejefb',
#  'aid_ZTF18abcxhcx',
#  'aid_ZTF18adiukvp',
#  'aid_ZTF18abgpxju',
#  'aid_ZTF18aawscgd',
#  'aid_ZTF18accfshs',
#  'aid_ZTF18aakdszt',
#  'aid_ZTF18aainceg',
#  'aid_ZTF20acuxihb',
#  'aid_ZTF18acibmuh',
#  'aid_ZTF20aasoxvi',
#  'aid_ZTF17aaahryy',
#  'aid_ZTF19aavkvpw',
#  'aid_ZTF18acbzlia',
#  'aid_ZTF18abdlffp',
#  'aid_ZTF18aaxljmv',
#  'aid_ZTF18aazwkpo',
#  'aid_ZTF18abslrtt',
#  'aid_ZTF22aabahpj',
#  'aid_ZTF19absjxub',
#  'aid_ZTF18aagrlyt',
#  'aid_ZTF18abotsfp',
#  'aid_ZTF19aalwpxo',
#  'aid_ZTF18adkulqu',
#  'aid_ZTF17aabvfyc',
#  'aid_ZTF17aaadzhb',
#  'aid_ZTF18aczomnf',
#  'aid_ZTF18acnbpkq',
#  'aid_ZTF18abcplbt',
#  'aid_ZTF18aaxdoeo',
#  'aid_ZTF20aakjugw',
#  'aid_ZTF18aairqym',
#  'aid_ZTF18abrrktt',
#  'aid_ZTF19adcprsb',
#  'aid_ZTF18aboszgg',
#  'aid_ZTF18abchvej',
#  'aid_ZTF17aaaennm',
#  'aid_ZTF18ablffmb',
#  'aid_ZTF18abfkwnj',
#  'aid_ZTF19aantoyd',
#  'aid_ZTF23ablpfnb',
#  'aid_ZTF18aayfaep',
#  'aid_ZTF18abdfgty',
#  'aid_ZTF18ablqwtm',
#  'aid_ZTF18acpdamm',
#  'aid_ZTF18abtpoyy',
#  'aid_ZTF18aajsgfz',
#  'aid_ZTF17aacmgyz',
#  'aid_ZTF21aarycyc',
#  'aid_ZTF19aazgdni',
#  'aid_ZTF18abdebbe',
#  'aid_ZTF18aberdql',
#  'aid_ZTF17aaclmen',
#  'aid_ZTF18abznowu',
#  'aid_ZTF18aastqga',
#  'aid_ZTF18aatpjry',
#  'aid_ZTF18abrcvgc',
#  'aid_ZTF20aaoqckq',
#  'aid_ZTF18aaksqxc',
#  'aid_ZTF23aaqxchq',
#  'aid_ZTF18aaueeok',
#  'aid_ZTF18admwhwt',
#  'aid_ZTF18abqcszt',
#  'aid_ZTF19aarfnrt',
#  'aid_ZTF18adivvmn',
#  'aid_ZTF18aaypaqv',
#  'aid_ZTF21aaepngi',
#  'aid_ZTF18aawlueh',
#  'aid_ZTF18aafvshp',
#  'aid_ZTF18abosvuq',
#  'aid_ZTF20abiqhgk',
#  'aid_ZTF18abwqzrr',
#  'aid_ZTF17aabskxi',
#  'aid_ZTF20aakziws',
#  'aid_ZTF18adasdnv',
#  'aid_ZTF19aaapjsg',
#  'aid_ZTF19aapiucn',
#  'aid_ZTF18aauhajw',
#  'aid_ZTF18abasgjf',
#  'aid_ZTF18adjwqpd',
#  'aid_ZTF18aakgwom',
#  'aid_ZTF18aakgukt',
#  'aid_ZTF19aasiynw',
#  'aid_ZTF18acbvzge',
#  'aid_ZTF19acdhddr',
#  'aid_ZTF18acdxptk',
#  'aid_ZTF18abjxkld',
#  'aid_ZTF18aaabblq',
#  'aid_ZTF19aarhrcv',
#  'aid_ZTF21abwjsud',
#  'aid_ZTF18aazwdaq',
#  'aid_ZTF18abblvgk',
#  'aid_ZTF18abolzpm',
#  'aid_ZTF23aaeffiu',
#  'aid_ZTF19aapxkce',
#  'aid_ZTF18aabycuw',
#  'aid_ZTF18abaxisw',
#  'aid_ZTF20acwpibi',
#  'aid_ZTF18abapgvo',
#  'aid_ZTF19aamkozb',
#  'aid_ZTF18abarehd',
#  'aid_ZTF22aaaelju',
#  'aid_ZTF17aaaehta',
#  'aid_ZTF18absunol',
#  'aid_ZTF18aaxpomi',
#  'aid_ZTF18absglmu',
#  'aid_ZTF18adjlunr',
#  'aid_ZTF17aaazlzl',
#  'aid_ZTF18aajyerc',
#  'aid_ZTF21acpyddn',
#  'aid_ZTF19aavydkd',
#  'aid_ZTF23aaapokf',
#  'aid_ZTF21abqhaib',
#  'aid_ZTF18aazewub',
#  'aid_ZTF18aawakeq',
#  'aid_ZTF18aaudxzk',
#  'aid_ZTF21acontmk',
#  'aid_ZTF20abekcdt',
#  'aid_ZTF18admodjt',
#  'aid_ZTF18abiklun',
#  'aid_ZTF20abqmejd',
#  'aid_ZTF18aayriab',
#  'aid_ZTF18abdfguy',
#  'aid_ZTF18admkvng',
#  'aid_ZTF19aarzaod',
#  'aid_ZTF18acrunqm',
#  'aid_ZTF19acesxsi',
#  'aid_ZTF18abkhzon',
#  'aid_ZTF18abznpxj',
#  'aid_ZTF18adkpcsr',
#  'aid_ZTF18aabwfwc',
#  'aid_ZTF19aauolpq',
#  'aid_ZTF18abkxdhk',
#  'aid_ZTF19aazwqcj',
#  'aid_ZTF18acwgbdk',
#  'aid_ZTF17aabwnhy',
#  'aid_ZTF17aabvfdr',
#  'aid_ZTF19aavjzwm',
#  'aid_ZTF20acxgztq',
#  'aid_ZTF19aarqllf',
#  'aid_ZTF18abmegbi',
#  'aid_ZTF21aajtstm',
#  'aid_ZTF18ablpycj',
#  'aid_ZTF19aacpxll',
#  'aid_ZTF18aabtugj',
#  'aid_ZTF20acpcpjn',
#  'aid_ZTF18acvcgor',
#  'aid_ZTF18acbbids',
#  'aid_ZTF17aaawggc',
#  'aid_ZTF18aagzmit',
#  'aid_ZTF18abjmfwg',
#  'aid_ZTF18aaalalo',
#  'aid_ZTF22aaabpqn',
#  'aid_ZTF19abppbcb',
#  'aid_ZTF18actawil',
#  'aid_ZTF19acxowrr',
#  'aid_ZTF18aabsiul',
#  'aid_ZTF20aammypi',
#  'aid_ZTF20aanrekj',
#  'aid_ZTF18aboshgu',
#  'aid_ZTF18aaxvbaa',
#  'aid_ZTF17aabtako',
#  'aid_ZTF18acfrlnq',
#  'aid_ZTF17aactvww',
#  'aid_ZTF18abmrgyc',
#  'aid_ZTF18adcavtb',
#  'aid_ZTF18abeakuc',
#  'aid_ZTF18abbfrte',
#  'aid_ZTF18abwnlmv',
#  'aid_ZTF19aalcvbc',
#  'aid_ZTF18aajtnii',
#  'aid_ZTF18achfyzy',
#  'aid_ZTF19aaxrnoe',
#  'aid_ZTF18abfysnw',
#  'aid_ZTF18acvwnje',
#  'aid_ZTF18acclsxx',
#  'aid_ZTF18aboeulq',
#  'aid_ZTF20aagzqsb',
#  'aid_ZTF21abuykso',
#  'aid_ZTF20abdzrxo',
#  'aid_ZTF18adkczmr',
#  'aid_ZTF20acxjqir',
#  'aid_ZTF18abakktw',
#  'aid_ZTF18aabpoqs',
#  'aid_ZTF19adhwkcf',
#  'aid_ZTF18admsfei',
#  'aid_ZTF19acthgxq',
#  'aid_ZTF18adbofiv',
#  'aid_ZTF22aajjasl',
#  'aid_ZTF18acwuylq',
#  'aid_ZTF18adbluxl',
#  'aid_ZTF18achumhw',
#  'aid_ZTF19aauxfiu',
#  'aid_ZTF19ackprzh',
#  'aid_ZTF18aayxoky',
#  'aid_ZTF21aaczpca',
#  'aid_ZTF18abajxas',
#  'aid_ZTF18abwnneo',
#  'aid_ZTF20abyaclq',
#  'aid_ZTF18abbvauv',
#  'aid_ZTF18abiipve',
#  'aid_ZTF18aagtgdd',
#  'aid_ZTF18aabipct',
#  'aid_ZTF18acchjug',
#  'aid_ZTF21aclyyfm',
#  'aid_ZTF20abntzmw',
#  'aid_ZTF18abclbvw',
#  'aid_ZTF18adaxqfz',
#  'aid_ZTF18aazmumh',
#  'aid_ZTF18abdfiii',
#  'aid_ZTF18aanvjqj',
#  'aid_ZTF18ablqdpy',
#  'aid_ZTF18abgmmhm',
#  'aid_ZTF18adbafkf',
#  'aid_ZTF20accmtgu',
#  'aid_ZTF18absgirr',
#  'aid_ZTF18aabibln',
#  'aid_ZTF17aabuvli',
#  'aid_ZTF22aagvrlq',
#  'aid_ZTF18aabkonv',
#  'aid_ZTF18abcvzkx',
#  'aid_ZTF20acehmtd',
#  'aid_ZTF19acsjeuy',
#  'aid_ZTF17aaafiml',
#  'aid_ZTF18abpptwd',
#  'aid_ZTF18aajrnii',
#  'aid_ZTF18aaelnse',
#  'aid_ZTF18aahwvpt',
#  'aid_ZTF18acafgee',
#  'aid_ZTF23aaahxvb',
#  'aid_ZTF18abdkuir',
#  'aid_ZTF18abgqbjk',
#  'aid_ZTF18acmvlwj',
#  'aid_ZTF17aaaxbyo',
#  'aid_ZTF20aavynba',
#  'aid_ZTF19aaadcog',
#  'aid_ZTF18aabprue',
#  'aid_ZTF19aaywnui',
#  'aid_ZTF18aazfghd',
#  'aid_ZTF22abdwecz',
#  'aid_ZTF18acwxufg',
#  'aid_ZTF20aasivpe',
#  'aid_ZTF18adbaeup',
#  'aid_ZTF17aaakgze',
#  'aid_ZTF18abltebf',
#  'aid_ZTF18abcoupk',
#  'aid_ZTF17aaaslvd',
#  'aid_ZTF18abwlupf',
#  'aid_ZTF21abezyhr',
#  'aid_ZTF18aazwdhb',
#  'aid_ZTF18abfzzuq',
#  'aid_ZTF17aabqidf',
#  'aid_ZTF18abccowc',
#  'aid_ZTF18aazvajs',
#  'aid_ZTF18aaajnkh',
#  'aid_ZTF18acnbgpw',
#  'aid_ZTF18abtoxjw',
#  'aid_ZTF18abeczqu',
#  'aid_ZTF18acampla',
#  'aid_ZTF19abxvmid',
#  'aid_ZTF20abzjcdg',
#  'aid_ZTF18accbbts',
#  'aid_ZTF18ableqbc',
#  'aid_ZTF18aaxcqrx',
#  'aid_ZTF18adjonum',
#  'aid_ZTF21achjxms',
#  'aid_ZTF19aaejtoy',
#  'aid_ZTF18abmapke',
#  'aid_ZTF18abcsuzv',
#  'aid_ZTF18aajvtbl',
#  'aid_ZTF18aceqxjc',
#  'aid_ZTF18abbtyxy',
#  'aid_ZTF19aaakxfw',
#  'aid_ZTF23aajtiqv',
#  'aid_ZTF18ablozdt',
#  'aid_ZTF20acxfkdz',
#  'aid_ZTF20acprmuv',
#  'aid_ZTF19aaaembe',
#  'aid_ZTF18aaovarz',
#  'aid_ZTF19abuvpbj',
#  'aid_ZTF21aawkflp',
#  'aid_ZTF18aaxuzxa',
#  'aid_ZTF18abskpmz',
#  'aid_ZTF22aaafpbi',
#  'aid_ZTF20aalrqbu',
#  'aid_ZTF20abeorzn',
#  'aid_ZTF19aadovbx',
#  'aid_ZTF20abpbqjx',
#  'aid_ZTF22abegjkl',
#  'aid_ZTF18aaapiex',
#  'aid_ZTF18acbujhw',
#  'aid_ZTF19aatubsj',
#  'aid_ZTF18abeqypr',
#  'aid_ZTF18aczecqk',
#  'aid_ZTF18abtscyb',
#  'aid_ZTF18abndzna',
#  'aid_ZTF18abblxym',
#  'aid_ZTF19aaapmva',
#  'aid_ZTF18aceywpj',
#  'aid_ZTF21aacpasn',
#  'aid_ZTF20abxyaje',
#  'aid_ZTF20acaazfz',
#  'aid_ZTF19acosnzi',
#  'aid_ZTF18abalejy',
#  'aid_ZTF18aaclpzr',
#  'aid_ZTF18acurkby',
#  'aid_ZTF21acdxhuv',
#  'aid_ZTF17aaapwkk',
#  'aid_ZTF19aaefkap',
#  'aid_ZTF18adqwurd',
#  'aid_ZTF22abthoha',
#  'aid_ZTF17aabureu',
#  'aid_ZTF18abwtcxj',
#  'aid_ZTF18aazlqnq',
#  'aid_ZTF21aaquzme',
#  'aid_ZTF17aaaecij',
#  'aid_ZTF18abmwqve',
#  'aid_ZTF19aadgpgo',
#  'aid_ZTF17aabwwgs',
#  'aid_ZTF18aaasgvl',
#  'aid_ZTF18aahxrde',
#  'aid_ZTF20acjqkmg',
#  'aid_ZTF18abctsue',
#  'aid_ZTF21aaepbbz',
#  'aid_ZTF22aagzcai',
#  'aid_ZTF19aaahqmv',
#  'aid_ZTF18abpybli',
#  'aid_ZTF23ababkmo',
#  'aid_ZTF17aabwpuh',
#  'aid_ZTF19acarbco',
#  'aid_ZTF20aaurfnl',
#  'aid_ZTF18aaxvbvz',
#  'aid_ZTF19aadoota',
#  'aid_ZTF18adiunwt',
#  'aid_ZTF19acsmbit',
#  'aid_ZTF19aaodbii',
#  'aid_ZTF18aabgjjd',
#  'aid_ZTF18abdbjdk',
#  'aid_ZTF18abmejlm',
#  'aid_ZTF17aabwoju',
#  'aid_ZTF18aaaxwqg',
#  'aid_ZTF18abadvtm',
#  'aid_ZTF18acdtsbp',
#  'aid_ZTF19abzqywg',
#  'aid_ZTF20aaksrbb',
#  'aid_ZTF21aahfqch',
#  'aid_ZTF18abpeqbh',
#  'aid_ZTF18admpveb',
#  'aid_ZTF18abshspo',
#  'aid_ZTF18abolvnm',
#  'aid_ZTF18aazwltl',
#  'aid_ZTF18abuqasd',
#  'aid_ZTF18abtjbfi',
#  'aid_ZTF18ablhrpz',
#  'aid_ZTF19abbxvmd',
#  'aid_ZTF19adfncji',
#  'aid_ZTF18aayhjoe',
#  'aid_ZTF18adpnwoz',
#  'aid_ZTF18abxejlg',
#  'aid_ZTF20aaifzfk',
#  'aid_ZTF18acefmps',
#  'aid_ZTF18aaxcxbu',
#  'aid_ZTF17aaagiaw',
#  'aid_ZTF20aawgbzp',
#  'aid_ZTF19aapxhmr',
#  'aid_ZTF19abijqjr',
#  'aid_ZTF21aaqoqhd',
#  'aid_ZTF17aaasnhm',
#  'aid_ZTF19aamqvre',
#  'aid_ZTF18adacoaj',
#  'aid_ZTF23aaasden',
#  'aid_ZTF18abkocxf',
#  'aid_ZTF18actzrbl',
#  'aid_ZTF18aauejqf',
#  'aid_ZTF18aditlpf',
#  'aid_ZTF18aauemmr',
#  'aid_ZTF18abfsagk',
#  'aid_ZTF18abgoqfm',
#  'aid_ZTF18acavmae',
#  'aid_ZTF18abccqmd',
#  'aid_ZTF18adbafdl',
#  'aid_ZTF18adjjjti',
#  'aid_ZTF18acuehfu',
#  'aid_ZTF18abjffzn',
#  'aid_ZTF21aagvhiq',
#  'aid_ZTF18aayhuvx',
#  'aid_ZTF18abnjuai',
#  'aid_ZTF19aaapoxs',
#  'aid_ZTF18abahutn',
#  'aid_ZTF18aaaawna',
#  'aid_ZTF18abtpibr',
#  'aid_ZTF19aaxdjuv',
#  'aid_ZTF18abaljmt',
#  'aid_ZTF18aastxzb',
#  'aid_ZTF20aaewazx',
#  'aid_ZTF20aaviaun',
#  'aid_ZTF21aagfttq',
#  'aid_ZTF20aamwcoo',
#  'aid_ZTF19aapzxlt',
#  'aid_ZTF18aaxymkg',
#  'aid_ZTF19aafntnd',
#  'aid_ZTF18absdebg',
#  'aid_ZTF18abjtfih',
#  'aid_ZTF20abfpili',
#  'aid_ZTF18aablbmx',
#  'aid_ZTF18aaxumgb',
#  'aid_ZTF18aauylrn',
#  'aid_ZTF20abppdch',
#  'aid_ZTF18aazepgp',
#  'aid_ZTF18acwafpt',
#  'aid_ZTF18aavsbzk',
#  'aid_ZTF17aaaeenw',
#  'aid_ZTF19abiapcd',
#  'aid_ZTF18abyymej',
#  'aid_ZTF18aabfdpx',
#  'aid_ZTF22abtoode',
#  'aid_ZTF18aalrhye',
#  'aid_ZTF18acyeoup',
#  'aid_ZTF18abzqsxk',
#  'aid_ZTF18abmodej',
#  'aid_ZTF18acswtoq',
#  'aid_ZTF18abnceez',
#  'aid_ZTF18acpkawc',
#  'aid_ZTF17aaaehyw',
#  'aid_ZTF18abqwlbs',
#  'aid_ZTF18acyvhjl',
#  'aid_ZTF21abaqjck',
#  'aid_ZTF19aardope',
#  'aid_ZTF18aaeuvya',
#  'aid_ZTF18aajteso',
#  'aid_ZTF18abmfmjo',
#  'aid_ZTF18abvjynv',
#  'aid_ZTF18abuykfm',
#  'aid_ZTF18abeglnm',
#  'aid_ZTF18abddgzu',
#  'aid_ZTF18abrymgx',
#  'aid_ZTF18abcuoop',
#  'aid_ZTF18aacdbzx',
#  'aid_ZTF17aabukkj',
#  'aid_ZTF19abdyxsl',
#  'aid_ZTF21aagkejs',
#  'aid_ZTF18abcdrxn',
#  'aid_ZTF18abccttv',
#  'aid_ZTF18absqjuh',
#  'aid_ZTF18abfkwub',
#  'aid_ZTF18admjewq',
#  'aid_ZTF18abjsdwi',
#  'aid_ZTF18abdeyvt',
#  'aid_ZTF18abjrcqc',
#  'aid_ZTF21aakicqr',
#  'aid_ZTF18acvwnmc',
#  'aid_ZTF18aabedzq',
#  'aid_ZTF18aamncub',
#  'aid_ZTF18aaxjfsi',
#  'aid_ZTF21aajawkm',
#  'aid_ZTF20acjtatk',
#  'aid_ZTF21aagacwn',
#  'aid_ZTF17aaawsma',
#  'aid_ZTF19aadyecz',
#  'aid_ZTF23abjkenm',
#  'aid_ZTF18abdlmxg',
#  'aid_ZTF18adlywka',
#  'aid_ZTF18abfkplr',
#  'aid_ZTF18aabktwo',
#  'aid_ZTF19aaabzpt',
#  'aid_ZTF19acsrqmd',
#  'aid_ZTF18aauqjtr',
#  'aid_ZTF18adizrar',
#  'aid_ZTF18achceld',
#  'aid_ZTF18acrvgcz',
#  'aid_ZTF19aacrnkw',
#  'aid_ZTF18abuxvfk',
#  'aid_ZTF20aaodmhs',
#  'aid_ZTF18abvgivy',
#  'aid_ZTF18aablqqi',
#  'aid_ZTF19aasbtzx',
#  'aid_ZTF19adalehh',
#  'aid_ZTF18abiglwi',
#  'aid_ZTF20aaycmhl',
#  'aid_ZTF18acmapoc',
#  'aid_ZTF18aabhxtz',
#  'aid_ZTF17aaarvma',
#  'aid_ZTF18acvenqx',
#  'aid_ZTF19aaabkqg',
#  'aid_ZTF18abuykic',
#  'aid_ZTF18aabglva',
#  'aid_ZTF19acjnxyl',
#  'aid_ZTF19aayazku',
#  'aid_ZTF19aavoxbb',
#  'aid_ZTF18acexzbr',
#  'aid_ZTF17aabvafj',
#  'aid_ZTF21aagtqfj',
#  'aid_ZTF18aaywgmj',
#  'aid_ZTF18aarohsl',
#  'aid_ZTF20abhclgp',
#  'aid_ZTF18aczerce',
#  'aid_ZTF18acrulfa',
#  'aid_ZTF18abgjgma',
#  'aid_ZTF18abcrrxw',
#  'aid_ZTF20aasnzni',
#  'aid_ZTF18aaaasvb',
#  'aid_ZTF19abagfte',
#  'aid_ZTF18aahipte',
#  'aid_ZTF18abaehsm',
#  'aid_ZTF18aaxwric',
#  'aid_ZTF17aaaxbmk',
#  'aid_ZTF18acbxkop',
#  'aid_ZTF18abnugbv',
#  'aid_ZTF19aakzash',
#  'aid_ZTF22abatqod',
#  'aid_ZTF20abapvxo',
#  'aid_ZTF19aaapuky',
#  'aid_ZTF19aavnwxf',
#  'aid_ZTF18abnzgsc',
#  'aid_ZTF18abmfmsz',
#  'aid_ZTF19accczms',
#  'aid_ZTF18abjiahm',
#  'aid_ZTF20acxzvqr',
#  'aid_ZTF18abvkthn',
#  'aid_ZTF17aacrlqg',
#  'aid_ZTF22aajmnjn',
#  'aid_ZTF18abeneqq',
#  'aid_ZTF18absgrxx',
#  'aid_ZTF18abmfsba',
#  'aid_ZTF21aammdnf',
#  'aid_ZTF18aaakzvf',
#  'aid_ZTF18aabsqjc',
#  'aid_ZTF20acuvyki',
#  'aid_ZTF18abcqmkn',
#  'aid_ZTF23aawmuis',
#  'aid_ZTF20aburywx',
#  'aid_ZTF18abwmwul',
#  'aid_ZTF18aawosun',
#  'aid_ZTF22aaudmvw',
#  'aid_ZTF20abpctsx',
#  'aid_ZTF18aaicobv',
#  'aid_ZTF23aamsekn',
#  'aid_ZTF21acbcjwa',
#  'aid_ZTF19aazpvdy',
#  'aid_ZTF19abmpwai',
#  'aid_ZTF19abfbaqr',
#  'aid_ZTF17aabuliw',
#  'aid_ZTF18abpybol',
#  'aid_ZTF19achoymp',
#  'aid_ZTF19aamrais',
#  'aid_ZTF18adayygu',
#  'aid_ZTF19achvvbg',
#  'aid_ZTF18acszimx',
#  'aid_ZTF18abwspau',
#  'aid_ZTF20abnorit',
#  'aid_ZTF19aajwvdn',
#  'aid_ZTF17aabprib',
#  'aid_ZTF21accwovq',
#  'aid_ZTF18aaitbkt',
#  'aid_ZTF18aaxysvu',
#  'aid_ZTF17aaburud',
#  'aid_ZTF18abhpvqw',
#  'aid_ZTF19aadendl',
#  'aid_ZTF18acihmwo',
#  'aid_ZTF19acvtrxj',
#  'aid_ZTF18abnbltx',
#  'aid_ZTF18abslxhz',
#  'aid_ZTF21aaovpas',
#  'aid_ZTF19aalwznk',
#  'aid_ZTF18abnuqzz',
#  'aid_ZTF22aafuind',
#  'aid_ZTF19aaxlgla',
#  'aid_ZTF18acdyxzv',
#  'aid_ZTF18aamndyk',
#  'aid_ZTF18abnzggz',
#  'aid_ZTF19adcehep',
#  'aid_ZTF19abagqpy',
#  'aid_ZTF17aaaeijf',
#  'aid_ZTF18abjpgik',
#  'aid_ZTF18aavzmal',
#  'aid_ZTF18abcrash',
#  'aid_ZTF19aavvvup',
#  'aid_ZTF20aarywtj',
#  'aid_ZTF19aayqqyk',
#  'aid_ZTF18abwkuxl',
#  'aid_ZTF18abmbczp',
#  'aid_ZTF18acgplgw',
#  'aid_ZTF18aaavkyj',
#  'aid_ZTF18aayhpmj',
#  'aid_ZTF19aassbza',
#  'aid_ZTF18abtgkhw',
#  'aid_ZTF18abuvygx',
#  'aid_ZTF21abcmzvk',
#  'aid_ZTF18achdelo',
#  'aid_ZTF21aatowyn',
#  'aid_ZTF18abctawb',
#  'aid_ZTF18abmxafd',
#  'aid_ZTF18acmdamo',
#  'aid_ZTF20aaaxnzb',
#  'aid_ZTF18adjiukn',
#  'aid_ZTF18aajsgkm',
#  'aid_ZTF18aaoasno',
#  'aid_ZTF20acitpfz',
#  'aid_ZTF18abeiwgm',
#  'aid_ZTF19aaimnvm',
#  'aid_ZTF23abccwbx',
#  'aid_ZTF19aavydpt',
#  'aid_ZTF22aaaygrp',
#  'aid_ZTF18abtpspd',
#  'aid_ZTF19acvmcdd',
#  'aid_ZTF18abchktr',
#  'aid_ZTF17aabupga',
#  'aid_ZTF20abqdkne',
#  'aid_ZTF17aackexx',
#  'aid_ZTF19aatmkll',
#  'aid_ZTF18abvtuxc',
#  'aid_ZTF19aacnvhi',
#  'aid_ZTF18aabtvhe',
#  'aid_ZTF20acmdkmr',
#  'aid_ZTF18aaisded',
#  'aid_ZTF18adasrhr',
#  'aid_ZTF20aadzwnu',
#  'aid_ZTF18aahiqst',
#  'aid_ZTF18adpbrsu',
#  'aid_ZTF18aabejvw',
#  'aid_ZTF18acuwybq',
#  'aid_ZTF18abcpqzm',
#  'aid_ZTF17aaaecsq',
#  'aid_ZTF18abmoduf',
#  'aid_ZTF21abconph',
#  'aid_ZTF17aabuvbl',
#  'aid_ZTF18abgsjpm',
#  'aid_ZTF18aavqmrk',
#  'aid_ZTF23aanqdlm',
#  'aid_ZTF18aarbvac',
#  'aid_ZTF18abnwull',
#  'aid_ZTF18abcxquh',
#  'aid_ZTF22abyoczz',
#  'aid_ZTF18abecynm',
#  'aid_ZTF22abzrbju',
#  'aid_ZTF18acfaoqv',
#  'aid_ZTF18aaagdij',
#  'aid_ZTF18aculjrg',
#  'aid_ZTF20adaxujq',
#  'aid_ZTF21acowsvk',
#  'aid_ZTF22abghgca',
#  'aid_ZTF18acwyxgc',
#  'aid_ZTF18aayxqek',
#  'aid_ZTF20acyxzyz',
#  'aid_ZTF18acenjnz',
#  'aid_ZTF18abadlek',
#  'aid_ZTF18abburkp',
#  'aid_ZTF17aabutlp',
#  'aid_ZTF21abhyqlv',
#  'aid_ZTF19adbecgj',
#  'aid_ZTF18abcxlra',
#  'aid_ZTF20acmntog',
#  'aid_ZTF19abcycqd',
#  'aid_ZTF18accergx',
#  'aid_ZTF21abcbwgq',
#  'aid_ZTF18abehhjh',
#  'aid_ZTF19aceipag',
#  'aid_ZTF17aaasltc',
#  'aid_ZTF17aaapvue',
#  'aid_ZTF17aaabdmt',
#  'aid_ZTF17aaafhpv',
#  'aid_ZTF18abcxgwj',
#  'aid_ZTF19aauezvf',
#  'aid_ZTF18acrdvug',
#  'aid_ZTF17aaanqai',
#  'aid_ZTF18aapocul',
#  'aid_ZTF18abmfwkj',
#  'aid_ZTF19aamvnkd',
#  'aid_ZTF18abikccd',
#  'aid_ZTF20acqvwzb',
#  'aid_ZTF18adkxnmz',
#  'aid_ZTF18aavqmlr',
#  'aid_ZTF17aaaiziw',
#  'aid_ZTF18abnuefl',
#  'aid_ZTF18aasnhlo',
#  'aid_ZTF18accbmvz',
#  'aid_ZTF21abgdeov',
#  'aid_ZTF18aaywnhi',
#  'aid_ZTF18abahiry',
#  'aid_ZTF18aawbiju',
#  'aid_ZTF18acskaqa',
#  'aid_ZTF17aaadynj',
#  'aid_ZTF18adngyax',
#  'aid_ZTF17aabuleq',
#  'aid_ZTF19aabmysp',
#  'aid_ZTF19aarguhg',
#  'aid_ZTF19aadbbct',
#  'aid_ZTF17aabpwzy',
#  'aid_ZTF20aancafz',
#  'aid_ZTF18adnclwb',
#  'aid_ZTF18aazwmxa',
#  'aid_ZTF19aadadqs',
#  'aid_ZTF17aaafzma',
#  'aid_ZTF18adjsnyh',
#  'aid_ZTF18abjmrxj',
#  'aid_ZTF18aaxuixm',
#  'aid_ZTF23abccont',
#  'aid_ZTF21abvykkf',
#  'aid_ZTF18aawdoyf',
#  'aid_ZTF18adakzxe',
#  'aid_ZTF18aazutqv',
#  'aid_ZTF20aaeltoa',
#  'aid_ZTF17aaaengk',
#  'aid_ZTF21aanswls',
#  'aid_ZTF18aabpsfs',
#  'aid_ZTF18abytelj',
#  'aid_ZTF18aabkbzw',
#  'aid_ZTF21abnudtb',
#  'aid_ZTF19aapwypq',
#  'aid_ZTF21abothvq',
#  'aid_ZTF19aaahffn',
#  'aid_ZTF17aaanyhq',
#  'aid_ZTF19abcejfo',
#  'aid_ZTF18abfnnnh',
#  'aid_ZTF18aaawbit',
#  'aid_ZTF18abeakvv',
#  'aid_ZTF18aaqqlaw',
#  'aid_ZTF18actypux',
#  'aid_ZTF18aawcdch',
#  'aid_ZTF18aaaeltb',
#  'aid_ZTF18aayqgie',
#  'aid_ZTF19aaammal',
#  'aid_ZTF18abtvijp',
#  'aid_ZTF18abobptn',
#  'aid_ZTF18adakztt',
#  'aid_ZTF17aaaeqhm',
#  'aid_ZTF18acvvtgg',
#  'aid_ZTF20aazymxi',
#  'aid_ZTF18acbzytc',
#  'aid_ZTF19aayjhpe',
#  'aid_ZTF18aayhhuc',
#  'aid_ZTF18accatez',
#  'aid_ZTF19aaafqns',
#  'aid_ZTF20aaskhqw',
#  'aid_ZTF21aalokhs',
#  'aid_ZTF19aaluldf',
#  'aid_ZTF22aaygscd',
#  'aid_ZTF18abatffv',
#  'aid_ZTF18aawmdpg',
#  'aid_ZTF17aaaeihg',
#  'aid_ZTF22absxatm',
#  'aid_ZTF20acmguhf',
#  'aid_ZTF18aaoecso',
#  'aid_ZTF18aakzkvs',
#  'aid_ZTF21aaphlty',
#  'aid_ZTF18abiwqhj',
#  'aid_ZTF19aaaezgh',
#  'aid_ZTF18aanbnwb',
#  'aid_ZTF18abycika',
#  'aid_ZTF19aatuyli',
#  'aid_ZTF18abscmhv',
#  'aid_ZTF20aapxpsb',
#  'aid_ZTF18aazpvze',
#  'aid_ZTF19aayeokv',
#  'aid_ZTF18abegecr',
#  'aid_ZTF18absuppe',
#  'aid_ZTF21ablgmxs',
#  'aid_ZTF19acbpzir',
#  'aid_ZTF17aabmwpe',
#  'aid_ZTF18absmgqy',
#  'aid_ZTF18ablplga',
#  'aid_ZTF17aabonqs',
#  'aid_ZTF18aawaeji',
#  'aid_ZTF18acszjrq',
#  'aid_ZTF17aaadayn',
#  'aid_ZTF18abpozuv',
#  'aid_ZTF18aaypoor',
#  'aid_ZTF19aabhwcf',
#  'aid_ZTF18abmxaxt',
#  'aid_ZTF17aaajkzm',
#  'aid_ZTF18adkgyhb',
#  'aid_ZTF18acuelax',
#  'aid_ZTF17aabwkkz',
#  'aid_ZTF18acyuups',
#  'aid_ZTF21aaeqpjr',
#  'aid_ZTF19acvrjzd',
#  'aid_ZTF18abaphqg',
#  'aid_ZTF18aczuwxv',
#  'aid_ZTF18abblyoh',
#  'aid_ZTF18abcxijx',
#  'aid_ZTF19abkgych',
#  'aid_ZTF18actxebc',
#  'aid_ZTF18abesmud',
#  'aid_ZTF18acyoisc',
#  'aid_ZTF18aaahyks',
#  'aid_ZTF19aapbjmb',
#  'aid_ZTF19aaxlhiz',
#  'aid_ZTF18abmjhzo',
#  'aid_ZTF18aavmrsf',
#  'aid_ZTF18abbvroe',
#  'aid_ZTF18abcnvwt',
#  'aid_ZTF19abbyxmb',
#  'aid_ZTF18ablvtbc',
#  'aid_ZTF18aaxczas',
#  'aid_ZTF17aaadyug',
#  'aid_ZTF17aaadjrt',
#  'aid_ZTF18aaxlsmq',
#  'aid_ZTF20acedqis',
#  'aid_ZTF18abeaisj',
#  'aid_ZTF18acryhyt',
#  'aid_ZTF19aabzttb',
#  'aid_ZTF19aaimiox',
#  'aid_ZTF23abeqble',
#  'aid_ZTF17aabvddo',
#  'aid_ZTF19abrcunk',
#  'aid_ZTF18aaxumqj',
#  'aid_ZTF18adfaovv',
#  'aid_ZTF18aavwurv',
#  'aid_ZTF19adcyeft',
#  'aid_ZTF18aaegrnn',
#  'aid_ZTF19abyubxn',
#  'aid_ZTF18aayoxka',
#  'aid_ZTF19abflnat',
#  'aid_ZTF21aaoqcnh',
#  'aid_ZTF18acetmcg',
#  'aid_ZTF18abkhcrc',
#  'aid_ZTF21aaqwjlz',
#  'aid_ZTF18abnzadn',
#  'aid_ZTF19aavbowl',
#  'aid_ZTF17aaarlrs',
#  'aid_ZTF22abayewb',
#  'aid_ZTF18aaadsii',
#  'aid_ZTF19aatvrhz',
#  'aid_ZTF18abzsyuc',
#  'aid_ZTF18adjowbf',
#  'aid_ZTF18abaeapi',
#  'aid_ZTF18abmrmuf',
#  'aid_ZTF20aamazzl',
#  'aid_ZTF18abchkpb',
#  'aid_ZTF18abwibgz',
#  'aid_ZTF21aagsxlu',
#  'aid_ZTF18aabjdmj',
#  'aid_ZTF18aacdvjp',
#  'aid_ZTF20aacdnck',
#  'aid_ZTF18abajxex',
#  'aid_ZTF19acawhvq',
#  'aid_ZTF18aayeknl',
#  'aid_ZTF17aaakijn',
#  'aid_ZTF17aabpnoy',
#  'aid_ZTF18ablrmha',
#  'aid_ZTF19aayeqse',
#  'aid_ZTF18abdlwso',
#  'aid_ZTF19aauyuof',
#  'aid_ZTF18aczepmh',
#  'aid_ZTF20abyxnjo',
#  'aid_ZTF18aarpwgw',
#  'aid_ZTF18aaadpya',
#  'aid_ZTF18acmywit',
#  'aid_ZTF19abyjswp',
#  'aid_ZTF18abcklsi',
#  'aid_ZTF18abmsbve',
#  'aid_ZTF18aaswenp',
#  'aid_ZTF18acryfmv',
#  'aid_ZTF18aajbhml',
#  'aid_ZTF18aazfdfo',
#  'aid_ZTF18abznpys',
#  'aid_ZTF20abajxia',
#  'aid_ZTF18acvgzun',
#  'aid_ZTF21aamqgzr',
#  'aid_ZTF18abaqgwg',
#  'aid_ZTF18acszhla',
#  'aid_ZTF19acyniwk',
#  'aid_ZTF20acmmiwq',
#  'aid_ZTF18aahxqhe',
#  'aid_ZTF18abmszjn',
#  'aid_ZTF18actwwor',
#  'aid_ZTF18abehcus',
#  'aid_ZTF18aabirgq',
#  'aid_ZTF17aabpmpn',
#  'aid_ZTF17aaagazp',
#  'aid_ZTF18abilbju',
#  'aid_ZTF18abmjmro',
#  'aid_ZTF19aasiigz',
#  'aid_ZTF22aacjliw',
#  'aid_ZTF18acbzrdr',
#  'aid_ZTF18abcjwmz',
#  'aid_ZTF19aayriyj',
#  'aid_ZTF18aabggxd',
#  'aid_ZTF18abtuznd',
#  'aid_ZTF20aaflcny',
#  'aid_ZTF20aarqovi',
#  'aid_ZTF20aasiwcu',
#  'aid_ZTF19acrcuxg',
#  'aid_ZTF18acpgecw',
#  'aid_ZTF18aavqmcb',
#  'aid_ZTF20acdbjev',
#  'aid_ZTF19aayvoqc',
#  'aid_ZTF17aabuuvs',
#  'aid_ZTF18aarkchp',
#  'aid_ZTF21abiricn',
#  'aid_ZTF17aabzwvl',
#  'aid_ZTF18abuqhbk',
#  'aid_ZTF18aavzkch',
#  'aid_ZTF18acyrsoj',
#  'aid_ZTF19aavxoos',
#  'aid_ZTF18abntyqw',
#  'aid_ZTF18aazjflo',
#  'aid_ZTF18aaakpoe',
#  'aid_ZTF20abmbznv',
#  'aid_ZTF19aaycngx',
#  'aid_ZTF18absbpid',
#  'aid_ZTF18aazvibw',
#  'aid_ZTF19aaaemwo',
#  'aid_ZTF18abcvenm',
#  'aid_ZTF17aaaqlfb',
#  'aid_ZTF18actwqpm',
#  'aid_ZTF18abcvfit',
#  'aid_ZTF18adjwaai',
#  'aid_ZTF18aammmyy',
#  'aid_ZTF18abbfzeh',
#  'aid_ZTF17aabuoxa',
#  'aid_ZTF18abadlfo',
#  'aid_ZTF23aagklwb',
#  'aid_ZTF18aaabicb',
#  'aid_ZTF18abrwqxt',
#  'aid_ZTF18abnusld',
#  'aid_ZTF18aainybs',
#  ...]

# %%
y_real_test.shape
# Out:
# (8328,)

# %%
len(obj_label)
# Out:
# 8328

# %%
mapping_classes = {col: i for i, col in enumerate(predictions.columns)}
mapping_classes_inverted = {v: k for k, v in mapping_classes.items()}
print(mapping_classes_inverted)
# Out:
# {0: 'AGN', 1: 'Blazar', 2: 'CEP', 3: 'CV/Nova', 4: 'DSCT', 5: 'EA', 6: 'EB/EW', 7: 'LPV', 8: 'Microlensing', 9: 'Periodic-Other', 10: 'QSO', 11: 'RRLab', 12: 'RRLc', 13: 'RSCVn', 14: 'SLSN', 15: 'SNII', 16: 'SNIIb', 17: 'SNIIn', 18: 'SNIa', 19: 'SNIbc', 20: 'TDE', 21: 'YSO', 22: 'shorten'}

# %%
def sort_dict_by_value(d, reverse=False):
    return dict(sorted(d.items(), key=lambda x: x[1], reverse=reverse))

sort_classes = list(sort_dict_by_value(mapping_classes).keys())
print(sort_classes)
# Out:
# ['AGN', 'Blazar', 'CEP', 'CV/Nova', 'DSCT', 'EA', 'EB/EW', 'LPV', 'Microlensing', 'Periodic-Other', 'QSO', 'RRLab', 'RRLc', 'RSCVn', 'SLSN', 'SNII', 'SNIIb', 'SNIIn', 'SNIa', 'SNIbc', 'TDE', 'YSO', 'shorten']

# %%
predictions
# Out:
#                        AGN    Blazar       CEP   CV/Nova      DSCT        EA  \
# index
# aid_ZTF17aaaocpq  0.274019  0.323965  0.008282  0.031802  0.000200  0.001479
# aid_ZTF17aaazbbb  0.629874  0.185243  0.001720  0.015746  0.000444  0.001086
# aid_ZTF17aaazlzl  0.408327  0.172802  0.004067  0.028232  0.001411  0.010718
# aid_ZTF17aaazuft  0.539812  0.193079  0.000763  0.004397  0.000230  0.000342
# aid_ZTF17aabhjci  0.260460  0.237665  0.019066  0.071313  0.000772  0.002793
# ...                    ...       ...       ...       ...       ...       ...
# aid_ZTF23aamaycf  0.084641  0.066134  0.013404  0.004160  0.000068  0.002840
# aid_ZTF23aaoscaj  0.036648  0.087262  0.045043  0.050203  0.014285  0.050833
# aid_ZTF23aappeda  0.013489  0.020425  0.051481  0.083976  0.008262  0.122116
# aid_ZTF23aazoggh  0.013716  0.031059  0.031766  0.089585  0.046332  0.048265
# aid_ZTF23abdyjve  0.038804  0.118179  0.014074  0.025008  0.001487  0.004085
#
#                      EB/EW       LPV  Microlensing  Periodic-Other  ...  \
# index                                                               ...
# aid_ZTF17aaaocpq  0.001386  0.039735      0.005580        0.002421  ...
# aid_ZTF17aaazbbb  0.000787  0.002478      0.000000        0.001524  ...
# aid_ZTF17aaazlzl  0.004368  0.006268      0.006507        0.006418  ...
# aid_ZTF17aaazuft  0.000220  0.003231      0.002192        0.001251  ...
# aid_ZTF17aabhjci  0.002440  0.009558      0.011998        0.003923  ...
# ...                    ...       ...           ...             ...  ...
# aid_ZTF23aamaycf  0.000685  0.019891      0.007628        0.001633  ...
# aid_ZTF23aaoscaj  0.026705  0.046977      0.126285        0.046988  ...
# aid_ZTF23aappeda  0.059358  0.012554      0.180265        0.026806  ...
# aid_ZTF23aazoggh  0.038729  0.013705      0.059407        0.106097  ...
# aid_ZTF23abdyjve  0.002749  0.113788      0.058715        0.009692  ...
#
#                      RSCVn      SLSN      SNII     SNIIb     SNIIn      SNIa  \
# index
# aid_ZTF17aaaocpq  0.004218  0.001649  0.001029  0.000231  0.002013  0.000731
# aid_ZTF17aaazbbb  0.004451  0.000865  0.000776  0.000451  0.001346  0.000563
# aid_ZTF17aaazlzl  0.007182  0.012353  0.022126  0.013199  0.028323  0.028211
# aid_ZTF17aaazuft  0.001155  0.001676  0.002415  0.001360  0.004359  0.003671
# aid_ZTF17aabhjci  0.009729  0.016334  0.020237  0.012147  0.044138  0.026238
# ...                    ...       ...       ...       ...       ...       ...
# aid_ZTF23aamaycf  0.007985  0.000499  0.000885  0.000295  0.000910  0.001292
# aid_ZTF23aaoscaj  0.055265  0.039126  0.015003  0.004889  0.022219  0.016454
# aid_ZTF23aappeda  0.033176  0.013771  0.008689  0.004237  0.012859  0.005574
# aid_ZTF23aazoggh  0.110053  0.009523  0.009256  0.005107  0.009795  0.009538
# aid_ZTF23abdyjve  0.004632  0.007812  0.001861  0.000577  0.003529  0.001904
#
#                      SNIbc       TDE       YSO  shorten
# index
# aid_ZTF17aaaocpq  0.000421  0.000936  0.231688     1024
# aid_ZTF17aaazbbb  0.000462  0.000823  0.092441     1024
# aid_ZTF17aaazlzl  0.021079  0.019514  0.157944     1024
# aid_ZTF17aaazuft  0.002460  0.001648  0.145894     1024
# aid_ZTF17aabhjci  0.015662  0.053918  0.119287     1024
# ...                    ...       ...       ...      ...
# aid_ZTF23aamaycf  0.000806  0.000524  0.758198     None
# aid_ZTF23aaoscaj  0.007513  0.029824  0.235021     None
# aid_ZTF23aappeda  0.009469  0.012581  0.259119     None
# aid_ZTF23aazoggh  0.009527  0.007924  0.300741     None
# aid_ZTF23abdyjve  0.002140  0.003580  0.483174     None
#
# [333496 rows x 23 columns]

# %%
obj_label
# Out:
# ['aid_ZTF18abnukht',
#  'aid_ZTF17aabxfzy',
#  'aid_ZTF18aazwmdx',
#  'aid_ZTF19aclfauc',
#  'aid_ZTF18aaodyyn',
#  'aid_ZTF17aabgoup',
#  'aid_ZTF18aawvlsj',
#  'aid_ZTF19abqanpy',
#  'aid_ZTF18abbulky',
#  'aid_ZTF19acyxuwh',
#  'aid_ZTF21achakto',
#  'aid_ZTF21acbqhoo',
#  'aid_ZTF20aaybvnb',
#  'aid_ZTF21aawztrg',
#  'aid_ZTF18achdntb',
#  'aid_ZTF18aaptcwa',
#  'aid_ZTF17aaafieu',
#  'aid_ZTF19aassknd',
#  'aid_ZTF17aaaeayf',
#  'aid_ZTF17aaasjea',
#  'aid_ZTF18aabhztc',
#  'aid_ZTF21accibae',
#  'aid_ZTF19aaaonud',
#  'aid_ZTF18achyqcq',
#  'aid_ZTF18abnttfy',
#  'aid_ZTF21aagkzve',
#  'aid_ZTF17aabusvp',
#  'aid_ZTF17aaahfho',
#  'aid_ZTF18abboazo',
#  'aid_ZTF20abegate',
#  'aid_ZTF18aclceyr',
#  'aid_ZTF18abbwwfs',
#  'aid_ZTF18abfzzul',
#  'aid_ZTF18aamhoda',
#  'aid_ZTF19acbtljt',
#  'aid_ZTF19aauojfb',
#  'aid_ZTF22abunqtv',
#  'aid_ZTF23abavrya',
#  'aid_ZTF18aaypawy',
#  'aid_ZTF21aaesdgz',
#  'aid_ZTF20aaofywo',
#  'aid_ZTF23aasrcyv',
#  'aid_ZTF20abmljfh',
#  'aid_ZTF18aaveqks',
#  'aid_ZTF19aazljri',
#  'aid_ZTF17aaainmx',
#  'aid_ZTF19aaakulz',
#  'aid_ZTF19aadotfg',
#  'aid_ZTF18aagxrle',
#  'aid_ZTF20aciuucu',
#  'aid_ZTF22aaanfjh',
#  'aid_ZTF19acxozhr',
#  'aid_ZTF18aazstcv',
#  'aid_ZTF18acsxflq',
#  'aid_ZTF19aaynrzv',
#  'aid_ZTF20abxawtg',
#  'aid_ZTF18abrntto',
#  'aid_ZTF18accvfbv',
#  'aid_ZTF17aaaocpq',
#  'aid_ZTF18abxdqpp',
#  'aid_ZTF18abjyrjv',
#  'aid_ZTF18adqkwtb',
#  'aid_ZTF18abchjdx',
#  'aid_ZTF18abuykiu',
#  'aid_ZTF18aatjlte',
#  'aid_ZTF20aabcjoq',
#  'aid_ZTF19aayumur',
#  'aid_ZTF18abmoqyf',
#  'aid_ZTF22aavdiim',
#  'aid_ZTF17aaaaaej',
#  'aid_ZTF18aaaeefe',
#  'aid_ZTF20acxdlcd',
#  'aid_ZTF18aagrjqm',
#  'aid_ZTF18abaamta',
#  'aid_ZTF21aaloxey',
#  'aid_ZTF22acahcqc',
#  'aid_ZTF18abebalg',
#  'aid_ZTF20acuaqlf',
#  'aid_ZTF18achkcym',
#  'aid_ZTF18acmrnrb',
#  'aid_ZTF17aadjzhj',
#  'aid_ZTF20acjbhhp',
#  'aid_ZTF18acwyqeg',
#  'aid_ZTF18acejefb',
#  'aid_ZTF18abcxhcx',
#  'aid_ZTF18adiukvp',
#  'aid_ZTF18abgpxju',
#  'aid_ZTF18aawscgd',
#  'aid_ZTF18accfshs',
#  'aid_ZTF18aakdszt',
#  'aid_ZTF18aainceg',
#  'aid_ZTF20acuxihb',
#  'aid_ZTF18acibmuh',
#  'aid_ZTF20aasoxvi',
#  'aid_ZTF17aaahryy',
#  'aid_ZTF19aavkvpw',
#  'aid_ZTF18acbzlia',
#  'aid_ZTF18abdlffp',
#  'aid_ZTF18aaxljmv',
#  'aid_ZTF18aazwkpo',
#  'aid_ZTF18abslrtt',
#  'aid_ZTF22aabahpj',
#  'aid_ZTF19absjxub',
#  'aid_ZTF18aagrlyt',
#  'aid_ZTF18abotsfp',
#  'aid_ZTF19aalwpxo',
#  'aid_ZTF18adkulqu',
#  'aid_ZTF17aabvfyc',
#  'aid_ZTF17aaadzhb',
#  'aid_ZTF18aczomnf',
#  'aid_ZTF18acnbpkq',
#  'aid_ZTF18abcplbt',
#  'aid_ZTF18aaxdoeo',
#  'aid_ZTF20aakjugw',
#  'aid_ZTF18aairqym',
#  'aid_ZTF18abrrktt',
#  'aid_ZTF19adcprsb',
#  'aid_ZTF18aboszgg',
#  'aid_ZTF18abchvej',
#  'aid_ZTF17aaaennm',
#  'aid_ZTF18ablffmb',
#  'aid_ZTF18abfkwnj',
#  'aid_ZTF19aantoyd',
#  'aid_ZTF23ablpfnb',
#  'aid_ZTF18aayfaep',
#  'aid_ZTF18abdfgty',
#  'aid_ZTF18ablqwtm',
#  'aid_ZTF18acpdamm',
#  'aid_ZTF18abtpoyy',
#  'aid_ZTF18aajsgfz',
#  'aid_ZTF17aacmgyz',
#  'aid_ZTF21aarycyc',
#  'aid_ZTF19aazgdni',
#  'aid_ZTF18abdebbe',
#  'aid_ZTF18aberdql',
#  'aid_ZTF17aaclmen',
#  'aid_ZTF18abznowu',
#  'aid_ZTF18aastqga',
#  'aid_ZTF18aatpjry',
#  'aid_ZTF18abrcvgc',
#  'aid_ZTF20aaoqckq',
#  'aid_ZTF18aaksqxc',
#  'aid_ZTF23aaqxchq',
#  'aid_ZTF18aaueeok',
#  'aid_ZTF18admwhwt',
#  'aid_ZTF18abqcszt',
#  'aid_ZTF19aarfnrt',
#  'aid_ZTF18adivvmn',
#  'aid_ZTF18aaypaqv',
#  'aid_ZTF21aaepngi',
#  'aid_ZTF18aawlueh',
#  'aid_ZTF18aafvshp',
#  'aid_ZTF18abosvuq',
#  'aid_ZTF20abiqhgk',
#  'aid_ZTF18abwqzrr',
#  'aid_ZTF17aabskxi',
#  'aid_ZTF20aakziws',
#  'aid_ZTF18adasdnv',
#  'aid_ZTF19aaapjsg',
#  'aid_ZTF19aapiucn',
#  'aid_ZTF18aauhajw',
#  'aid_ZTF18abasgjf',
#  'aid_ZTF18adjwqpd',
#  'aid_ZTF18aakgwom',
#  'aid_ZTF18aakgukt',
#  'aid_ZTF19aasiynw',
#  'aid_ZTF18acbvzge',
#  'aid_ZTF19acdhddr',
#  'aid_ZTF18acdxptk',
#  'aid_ZTF18abjxkld',
#  'aid_ZTF18aaabblq',
#  'aid_ZTF19aarhrcv',
#  'aid_ZTF21abwjsud',
#  'aid_ZTF18aazwdaq',
#  'aid_ZTF18abblvgk',
#  'aid_ZTF18abolzpm',
#  'aid_ZTF23aaeffiu',
#  'aid_ZTF19aapxkce',
#  'aid_ZTF18aabycuw',
#  'aid_ZTF18abaxisw',
#  'aid_ZTF20acwpibi',
#  'aid_ZTF18abapgvo',
#  'aid_ZTF19aamkozb',
#  'aid_ZTF18abarehd',
#  'aid_ZTF22aaaelju',
#  'aid_ZTF17aaaehta',
#  'aid_ZTF18absunol',
#  'aid_ZTF18aaxpomi',
#  'aid_ZTF18absglmu',
#  'aid_ZTF18adjlunr',
#  'aid_ZTF17aaazlzl',
#  'aid_ZTF18aajyerc',
#  'aid_ZTF21acpyddn',
#  'aid_ZTF19aavydkd',
#  'aid_ZTF23aaapokf',
#  'aid_ZTF21abqhaib',
#  'aid_ZTF18aazewub',
#  'aid_ZTF18aawakeq',
#  'aid_ZTF18aaudxzk',
#  'aid_ZTF21acontmk',
#  'aid_ZTF20abekcdt',
#  'aid_ZTF18admodjt',
#  'aid_ZTF18abiklun',
#  'aid_ZTF20abqmejd',
#  'aid_ZTF18aayriab',
#  'aid_ZTF18abdfguy',
#  'aid_ZTF18admkvng',
#  'aid_ZTF19aarzaod',
#  'aid_ZTF18acrunqm',
#  'aid_ZTF19acesxsi',
#  'aid_ZTF18abkhzon',
#  'aid_ZTF18abznpxj',
#  'aid_ZTF18adkpcsr',
#  'aid_ZTF18aabwfwc',
#  'aid_ZTF19aauolpq',
#  'aid_ZTF18abkxdhk',
#  'aid_ZTF19aazwqcj',
#  'aid_ZTF18acwgbdk',
#  'aid_ZTF17aabwnhy',
#  'aid_ZTF17aabvfdr',
#  'aid_ZTF19aavjzwm',
#  'aid_ZTF20acxgztq',
#  'aid_ZTF19aarqllf',
#  'aid_ZTF18abmegbi',
#  'aid_ZTF21aajtstm',
#  'aid_ZTF18ablpycj',
#  'aid_ZTF19aacpxll',
#  'aid_ZTF18aabtugj',
#  'aid_ZTF20acpcpjn',
#  'aid_ZTF18acvcgor',
#  'aid_ZTF18acbbids',
#  'aid_ZTF17aaawggc',
#  'aid_ZTF18aagzmit',
#  'aid_ZTF18abjmfwg',
#  'aid_ZTF18aaalalo',
#  'aid_ZTF22aaabpqn',
#  'aid_ZTF19abppbcb',
#  'aid_ZTF18actawil',
#  'aid_ZTF19acxowrr',
#  'aid_ZTF18aabsiul',
#  'aid_ZTF20aammypi',
#  'aid_ZTF20aanrekj',
#  'aid_ZTF18aboshgu',
#  'aid_ZTF18aaxvbaa',
#  'aid_ZTF17aabtako',
#  'aid_ZTF18acfrlnq',
#  'aid_ZTF17aactvww',
#  'aid_ZTF18abmrgyc',
#  'aid_ZTF18adcavtb',
#  'aid_ZTF18abeakuc',
#  'aid_ZTF18abbfrte',
#  'aid_ZTF18abwnlmv',
#  'aid_ZTF19aalcvbc',
#  'aid_ZTF18aajtnii',
#  'aid_ZTF18achfyzy',
#  'aid_ZTF19aaxrnoe',
#  'aid_ZTF18abfysnw',
#  'aid_ZTF18acvwnje',
#  'aid_ZTF18acclsxx',
#  'aid_ZTF18aboeulq',
#  'aid_ZTF20aagzqsb',
#  'aid_ZTF21abuykso',
#  'aid_ZTF20abdzrxo',
#  'aid_ZTF18adkczmr',
#  'aid_ZTF20acxjqir',
#  'aid_ZTF18abakktw',
#  'aid_ZTF18aabpoqs',
#  'aid_ZTF19adhwkcf',
#  'aid_ZTF18admsfei',
#  'aid_ZTF19acthgxq',
#  'aid_ZTF18adbofiv',
#  'aid_ZTF22aajjasl',
#  'aid_ZTF18acwuylq',
#  'aid_ZTF18adbluxl',
#  'aid_ZTF18achumhw',
#  'aid_ZTF19aauxfiu',
#  'aid_ZTF19ackprzh',
#  'aid_ZTF18aayxoky',
#  'aid_ZTF21aaczpca',
#  'aid_ZTF18abajxas',
#  'aid_ZTF18abwnneo',
#  'aid_ZTF20abyaclq',
#  'aid_ZTF18abbvauv',
#  'aid_ZTF18abiipve',
#  'aid_ZTF18aagtgdd',
#  'aid_ZTF18aabipct',
#  'aid_ZTF18acchjug',
#  'aid_ZTF21aclyyfm',
#  'aid_ZTF20abntzmw',
#  'aid_ZTF18abclbvw',
#  'aid_ZTF18adaxqfz',
#  'aid_ZTF18aazmumh',
#  'aid_ZTF18abdfiii',
#  'aid_ZTF18aanvjqj',
#  'aid_ZTF18ablqdpy',
#  'aid_ZTF18abgmmhm',
#  'aid_ZTF18adbafkf',
#  'aid_ZTF20accmtgu',
#  'aid_ZTF18absgirr',
#  'aid_ZTF18aabibln',
#  'aid_ZTF17aabuvli',
#  'aid_ZTF22aagvrlq',
#  'aid_ZTF18aabkonv',
#  'aid_ZTF18abcvzkx',
#  'aid_ZTF20acehmtd',
#  'aid_ZTF19acsjeuy',
#  'aid_ZTF17aaafiml',
#  'aid_ZTF18abpptwd',
#  'aid_ZTF18aajrnii',
#  'aid_ZTF18aaelnse',
#  'aid_ZTF18aahwvpt',
#  'aid_ZTF18acafgee',
#  'aid_ZTF23aaahxvb',
#  'aid_ZTF18abdkuir',
#  'aid_ZTF18abgqbjk',
#  'aid_ZTF18acmvlwj',
#  'aid_ZTF17aaaxbyo',
#  'aid_ZTF20aavynba',
#  'aid_ZTF19aaadcog',
#  'aid_ZTF18aabprue',
#  'aid_ZTF19aaywnui',
#  'aid_ZTF18aazfghd',
#  'aid_ZTF22abdwecz',
#  'aid_ZTF18acwxufg',
#  'aid_ZTF20aasivpe',
#  'aid_ZTF18adbaeup',
#  'aid_ZTF17aaakgze',
#  'aid_ZTF18abltebf',
#  'aid_ZTF18abcoupk',
#  'aid_ZTF17aaaslvd',
#  'aid_ZTF18abwlupf',
#  'aid_ZTF21abezyhr',
#  'aid_ZTF18aazwdhb',
#  'aid_ZTF18abfzzuq',
#  'aid_ZTF17aabqidf',
#  'aid_ZTF18abccowc',
#  'aid_ZTF18aazvajs',
#  'aid_ZTF18aaajnkh',
#  'aid_ZTF18acnbgpw',
#  'aid_ZTF18abtoxjw',
#  'aid_ZTF18abeczqu',
#  'aid_ZTF18acampla',
#  'aid_ZTF19abxvmid',
#  'aid_ZTF20abzjcdg',
#  'aid_ZTF18accbbts',
#  'aid_ZTF18ableqbc',
#  'aid_ZTF18aaxcqrx',
#  'aid_ZTF18adjonum',
#  'aid_ZTF21achjxms',
#  'aid_ZTF19aaejtoy',
#  'aid_ZTF18abmapke',
#  'aid_ZTF18abcsuzv',
#  'aid_ZTF18aajvtbl',
#  'aid_ZTF18aceqxjc',
#  'aid_ZTF18abbtyxy',
#  'aid_ZTF19aaakxfw',
#  'aid_ZTF23aajtiqv',
#  'aid_ZTF18ablozdt',
#  'aid_ZTF20acxfkdz',
#  'aid_ZTF20acprmuv',
#  'aid_ZTF19aaaembe',
#  'aid_ZTF18aaovarz',
#  'aid_ZTF19abuvpbj',
#  'aid_ZTF21aawkflp',
#  'aid_ZTF18aaxuzxa',
#  'aid_ZTF18abskpmz',
#  'aid_ZTF22aaafpbi',
#  'aid_ZTF20aalrqbu',
#  'aid_ZTF20abeorzn',
#  'aid_ZTF19aadovbx',
#  'aid_ZTF20abpbqjx',
#  'aid_ZTF22abegjkl',
#  'aid_ZTF18aaapiex',
#  'aid_ZTF18acbujhw',
#  'aid_ZTF19aatubsj',
#  'aid_ZTF18abeqypr',
#  'aid_ZTF18aczecqk',
#  'aid_ZTF18abtscyb',
#  'aid_ZTF18abndzna',
#  'aid_ZTF18abblxym',
#  'aid_ZTF19aaapmva',
#  'aid_ZTF18aceywpj',
#  'aid_ZTF21aacpasn',
#  'aid_ZTF20abxyaje',
#  'aid_ZTF20acaazfz',
#  'aid_ZTF19acosnzi',
#  'aid_ZTF18abalejy',
#  'aid_ZTF18aaclpzr',
#  'aid_ZTF18acurkby',
#  'aid_ZTF21acdxhuv',
#  'aid_ZTF17aaapwkk',
#  'aid_ZTF19aaefkap',
#  'aid_ZTF18adqwurd',
#  'aid_ZTF22abthoha',
#  'aid_ZTF17aabureu',
#  'aid_ZTF18abwtcxj',
#  'aid_ZTF18aazlqnq',
#  'aid_ZTF21aaquzme',
#  'aid_ZTF17aaaecij',
#  'aid_ZTF18abmwqve',
#  'aid_ZTF19aadgpgo',
#  'aid_ZTF17aabwwgs',
#  'aid_ZTF18aaasgvl',
#  'aid_ZTF18aahxrde',
#  'aid_ZTF20acjqkmg',
#  'aid_ZTF18abctsue',
#  'aid_ZTF21aaepbbz',
#  'aid_ZTF22aagzcai',
#  'aid_ZTF19aaahqmv',
#  'aid_ZTF18abpybli',
#  'aid_ZTF23ababkmo',
#  'aid_ZTF17aabwpuh',
#  'aid_ZTF19acarbco',
#  'aid_ZTF20aaurfnl',
#  'aid_ZTF18aaxvbvz',
#  'aid_ZTF19aadoota',
#  'aid_ZTF18adiunwt',
#  'aid_ZTF19acsmbit',
#  'aid_ZTF19aaodbii',
#  'aid_ZTF18aabgjjd',
#  'aid_ZTF18abdbjdk',
#  'aid_ZTF18abmejlm',
#  'aid_ZTF17aabwoju',
#  'aid_ZTF18aaaxwqg',
#  'aid_ZTF18abadvtm',
#  'aid_ZTF18acdtsbp',
#  'aid_ZTF19abzqywg',
#  'aid_ZTF20aaksrbb',
#  'aid_ZTF21aahfqch',
#  'aid_ZTF18abpeqbh',
#  'aid_ZTF18admpveb',
#  'aid_ZTF18abshspo',
#  'aid_ZTF18abolvnm',
#  'aid_ZTF18aazwltl',
#  'aid_ZTF18abuqasd',
#  'aid_ZTF18abtjbfi',
#  'aid_ZTF18ablhrpz',
#  'aid_ZTF19abbxvmd',
#  'aid_ZTF19adfncji',
#  'aid_ZTF18aayhjoe',
#  'aid_ZTF18adpnwoz',
#  'aid_ZTF18abxejlg',
#  'aid_ZTF20aaifzfk',
#  'aid_ZTF18acefmps',
#  'aid_ZTF18aaxcxbu',
#  'aid_ZTF17aaagiaw',
#  'aid_ZTF20aawgbzp',
#  'aid_ZTF19aapxhmr',
#  'aid_ZTF19abijqjr',
#  'aid_ZTF21aaqoqhd',
#  'aid_ZTF17aaasnhm',
#  'aid_ZTF19aamqvre',
#  'aid_ZTF18adacoaj',
#  'aid_ZTF23aaasden',
#  'aid_ZTF18abkocxf',
#  'aid_ZTF18actzrbl',
#  'aid_ZTF18aauejqf',
#  'aid_ZTF18aditlpf',
#  'aid_ZTF18aauemmr',
#  'aid_ZTF18abfsagk',
#  'aid_ZTF18abgoqfm',
#  'aid_ZTF18acavmae',
#  'aid_ZTF18abccqmd',
#  'aid_ZTF18adbafdl',
#  'aid_ZTF18adjjjti',
#  'aid_ZTF18acuehfu',
#  'aid_ZTF18abjffzn',
#  'aid_ZTF21aagvhiq',
#  'aid_ZTF18aayhuvx',
#  'aid_ZTF18abnjuai',
#  'aid_ZTF19aaapoxs',
#  'aid_ZTF18abahutn',
#  'aid_ZTF18aaaawna',
#  'aid_ZTF18abtpibr',
#  'aid_ZTF19aaxdjuv',
#  'aid_ZTF18abaljmt',
#  'aid_ZTF18aastxzb',
#  'aid_ZTF20aaewazx',
#  'aid_ZTF20aaviaun',
#  'aid_ZTF21aagfttq',
#  'aid_ZTF20aamwcoo',
#  'aid_ZTF19aapzxlt',
#  'aid_ZTF18aaxymkg',
#  'aid_ZTF19aafntnd',
#  'aid_ZTF18absdebg',
#  'aid_ZTF18abjtfih',
#  'aid_ZTF20abfpili',
#  'aid_ZTF18aablbmx',
#  'aid_ZTF18aaxumgb',
#  'aid_ZTF18aauylrn',
#  'aid_ZTF20abppdch',
#  'aid_ZTF18aazepgp',
#  'aid_ZTF18acwafpt',
#  'aid_ZTF18aavsbzk',
#  'aid_ZTF17aaaeenw',
#  'aid_ZTF19abiapcd',
#  'aid_ZTF18abyymej',
#  'aid_ZTF18aabfdpx',
#  'aid_ZTF22abtoode',
#  'aid_ZTF18aalrhye',
#  'aid_ZTF18acyeoup',
#  'aid_ZTF18abzqsxk',
#  'aid_ZTF18abmodej',
#  'aid_ZTF18acswtoq',
#  'aid_ZTF18abnceez',
#  'aid_ZTF18acpkawc',
#  'aid_ZTF17aaaehyw',
#  'aid_ZTF18abqwlbs',
#  'aid_ZTF18acyvhjl',
#  'aid_ZTF21abaqjck',
#  'aid_ZTF19aardope',
#  'aid_ZTF18aaeuvya',
#  'aid_ZTF18aajteso',
#  'aid_ZTF18abmfmjo',
#  'aid_ZTF18abvjynv',
#  'aid_ZTF18abuykfm',
#  'aid_ZTF18abeglnm',
#  'aid_ZTF18abddgzu',
#  'aid_ZTF18abrymgx',
#  'aid_ZTF18abcuoop',
#  'aid_ZTF18aacdbzx',
#  'aid_ZTF17aabukkj',
#  'aid_ZTF19abdyxsl',
#  'aid_ZTF21aagkejs',
#  'aid_ZTF18abcdrxn',
#  'aid_ZTF18abccttv',
#  'aid_ZTF18absqjuh',
#  'aid_ZTF18abfkwub',
#  'aid_ZTF18admjewq',
#  'aid_ZTF18abjsdwi',
#  'aid_ZTF18abdeyvt',
#  'aid_ZTF18abjrcqc',
#  'aid_ZTF21aakicqr',
#  'aid_ZTF18acvwnmc',
#  'aid_ZTF18aabedzq',
#  'aid_ZTF18aamncub',
#  'aid_ZTF18aaxjfsi',
#  'aid_ZTF21aajawkm',
#  'aid_ZTF20acjtatk',
#  'aid_ZTF21aagacwn',
#  'aid_ZTF17aaawsma',
#  'aid_ZTF19aadyecz',
#  'aid_ZTF23abjkenm',
#  'aid_ZTF18abdlmxg',
#  'aid_ZTF18adlywka',
#  'aid_ZTF18abfkplr',
#  'aid_ZTF18aabktwo',
#  'aid_ZTF19aaabzpt',
#  'aid_ZTF19acsrqmd',
#  'aid_ZTF18aauqjtr',
#  'aid_ZTF18adizrar',
#  'aid_ZTF18achceld',
#  'aid_ZTF18acrvgcz',
#  'aid_ZTF19aacrnkw',
#  'aid_ZTF18abuxvfk',
#  'aid_ZTF20aaodmhs',
#  'aid_ZTF18abvgivy',
#  'aid_ZTF18aablqqi',
#  'aid_ZTF19aasbtzx',
#  'aid_ZTF19adalehh',
#  'aid_ZTF18abiglwi',
#  'aid_ZTF20aaycmhl',
#  'aid_ZTF18acmapoc',
#  'aid_ZTF18aabhxtz',
#  'aid_ZTF17aaarvma',
#  'aid_ZTF18acvenqx',
#  'aid_ZTF19aaabkqg',
#  'aid_ZTF18abuykic',
#  'aid_ZTF18aabglva',
#  'aid_ZTF19acjnxyl',
#  'aid_ZTF19aayazku',
#  'aid_ZTF19aavoxbb',
#  'aid_ZTF18acexzbr',
#  'aid_ZTF17aabvafj',
#  'aid_ZTF21aagtqfj',
#  'aid_ZTF18aaywgmj',
#  'aid_ZTF18aarohsl',
#  'aid_ZTF20abhclgp',
#  'aid_ZTF18aczerce',
#  'aid_ZTF18acrulfa',
#  'aid_ZTF18abgjgma',
#  'aid_ZTF18abcrrxw',
#  'aid_ZTF20aasnzni',
#  'aid_ZTF18aaaasvb',
#  'aid_ZTF19abagfte',
#  'aid_ZTF18aahipte',
#  'aid_ZTF18abaehsm',
#  'aid_ZTF18aaxwric',
#  'aid_ZTF17aaaxbmk',
#  'aid_ZTF18acbxkop',
#  'aid_ZTF18abnugbv',
#  'aid_ZTF19aakzash',
#  'aid_ZTF22abatqod',
#  'aid_ZTF20abapvxo',
#  'aid_ZTF19aaapuky',
#  'aid_ZTF19aavnwxf',
#  'aid_ZTF18abnzgsc',
#  'aid_ZTF18abmfmsz',
#  'aid_ZTF19accczms',
#  'aid_ZTF18abjiahm',
#  'aid_ZTF20acxzvqr',
#  'aid_ZTF18abvkthn',
#  'aid_ZTF17aacrlqg',
#  'aid_ZTF22aajmnjn',
#  'aid_ZTF18abeneqq',
#  'aid_ZTF18absgrxx',
#  'aid_ZTF18abmfsba',
#  'aid_ZTF21aammdnf',
#  'aid_ZTF18aaakzvf',
#  'aid_ZTF18aabsqjc',
#  'aid_ZTF20acuvyki',
#  'aid_ZTF18abcqmkn',
#  'aid_ZTF23aawmuis',
#  'aid_ZTF20aburywx',
#  'aid_ZTF18abwmwul',
#  'aid_ZTF18aawosun',
#  'aid_ZTF22aaudmvw',
#  'aid_ZTF20abpctsx',
#  'aid_ZTF18aaicobv',
#  'aid_ZTF23aamsekn',
#  'aid_ZTF21acbcjwa',
#  'aid_ZTF19aazpvdy',
#  'aid_ZTF19abmpwai',
#  'aid_ZTF19abfbaqr',
#  'aid_ZTF17aabuliw',
#  'aid_ZTF18abpybol',
#  'aid_ZTF19achoymp',
#  'aid_ZTF19aamrais',
#  'aid_ZTF18adayygu',
#  'aid_ZTF19achvvbg',
#  'aid_ZTF18acszimx',
#  'aid_ZTF18abwspau',
#  'aid_ZTF20abnorit',
#  'aid_ZTF19aajwvdn',
#  'aid_ZTF17aabprib',
#  'aid_ZTF21accwovq',
#  'aid_ZTF18aaitbkt',
#  'aid_ZTF18aaxysvu',
#  'aid_ZTF17aaburud',
#  'aid_ZTF18abhpvqw',
#  'aid_ZTF19aadendl',
#  'aid_ZTF18acihmwo',
#  'aid_ZTF19acvtrxj',
#  'aid_ZTF18abnbltx',
#  'aid_ZTF18abslxhz',
#  'aid_ZTF21aaovpas',
#  'aid_ZTF19aalwznk',
#  'aid_ZTF18abnuqzz',
#  'aid_ZTF22aafuind',
#  'aid_ZTF19aaxlgla',
#  'aid_ZTF18acdyxzv',
#  'aid_ZTF18aamndyk',
#  'aid_ZTF18abnzggz',
#  'aid_ZTF19adcehep',
#  'aid_ZTF19abagqpy',
#  'aid_ZTF17aaaeijf',
#  'aid_ZTF18abjpgik',
#  'aid_ZTF18aavzmal',
#  'aid_ZTF18abcrash',
#  'aid_ZTF19aavvvup',
#  'aid_ZTF20aarywtj',
#  'aid_ZTF19aayqqyk',
#  'aid_ZTF18abwkuxl',
#  'aid_ZTF18abmbczp',
#  'aid_ZTF18acgplgw',
#  'aid_ZTF18aaavkyj',
#  'aid_ZTF18aayhpmj',
#  'aid_ZTF19aassbza',
#  'aid_ZTF18abtgkhw',
#  'aid_ZTF18abuvygx',
#  'aid_ZTF21abcmzvk',
#  'aid_ZTF18achdelo',
#  'aid_ZTF21aatowyn',
#  'aid_ZTF18abctawb',
#  'aid_ZTF18abmxafd',
#  'aid_ZTF18acmdamo',
#  'aid_ZTF20aaaxnzb',
#  'aid_ZTF18adjiukn',
#  'aid_ZTF18aajsgkm',
#  'aid_ZTF18aaoasno',
#  'aid_ZTF20acitpfz',
#  'aid_ZTF18abeiwgm',
#  'aid_ZTF19aaimnvm',
#  'aid_ZTF23abccwbx',
#  'aid_ZTF19aavydpt',
#  'aid_ZTF22aaaygrp',
#  'aid_ZTF18abtpspd',
#  'aid_ZTF19acvmcdd',
#  'aid_ZTF18abchktr',
#  'aid_ZTF17aabupga',
#  'aid_ZTF20abqdkne',
#  'aid_ZTF17aackexx',
#  'aid_ZTF19aatmkll',
#  'aid_ZTF18abvtuxc',
#  'aid_ZTF19aacnvhi',
#  'aid_ZTF18aabtvhe',
#  'aid_ZTF20acmdkmr',
#  'aid_ZTF18aaisded',
#  'aid_ZTF18adasrhr',
#  'aid_ZTF20aadzwnu',
#  'aid_ZTF18aahiqst',
#  'aid_ZTF18adpbrsu',
#  'aid_ZTF18aabejvw',
#  'aid_ZTF18acuwybq',
#  'aid_ZTF18abcpqzm',
#  'aid_ZTF17aaaecsq',
#  'aid_ZTF18abmoduf',
#  'aid_ZTF21abconph',
#  'aid_ZTF17aabuvbl',
#  'aid_ZTF18abgsjpm',
#  'aid_ZTF18aavqmrk',
#  'aid_ZTF23aanqdlm',
#  'aid_ZTF18aarbvac',
#  'aid_ZTF18abnwull',
#  'aid_ZTF18abcxquh',
#  'aid_ZTF22abyoczz',
#  'aid_ZTF18abecynm',
#  'aid_ZTF22abzrbju',
#  'aid_ZTF18acfaoqv',
#  'aid_ZTF18aaagdij',
#  'aid_ZTF18aculjrg',
#  'aid_ZTF20adaxujq',
#  'aid_ZTF21acowsvk',
#  'aid_ZTF22abghgca',
#  'aid_ZTF18acwyxgc',
#  'aid_ZTF18aayxqek',
#  'aid_ZTF20acyxzyz',
#  'aid_ZTF18acenjnz',
#  'aid_ZTF18abadlek',
#  'aid_ZTF18abburkp',
#  'aid_ZTF17aabutlp',
#  'aid_ZTF21abhyqlv',
#  'aid_ZTF19adbecgj',
#  'aid_ZTF18abcxlra',
#  'aid_ZTF20acmntog',
#  'aid_ZTF19abcycqd',
#  'aid_ZTF18accergx',
#  'aid_ZTF21abcbwgq',
#  'aid_ZTF18abehhjh',
#  'aid_ZTF19aceipag',
#  'aid_ZTF17aaasltc',
#  'aid_ZTF17aaapvue',
#  'aid_ZTF17aaabdmt',
#  'aid_ZTF17aaafhpv',
#  'aid_ZTF18abcxgwj',
#  'aid_ZTF19aauezvf',
#  'aid_ZTF18acrdvug',
#  'aid_ZTF17aaanqai',
#  'aid_ZTF18aapocul',
#  'aid_ZTF18abmfwkj',
#  'aid_ZTF19aamvnkd',
#  'aid_ZTF18abikccd',
#  'aid_ZTF20acqvwzb',
#  'aid_ZTF18adkxnmz',
#  'aid_ZTF18aavqmlr',
#  'aid_ZTF17aaaiziw',
#  'aid_ZTF18abnuefl',
#  'aid_ZTF18aasnhlo',
#  'aid_ZTF18accbmvz',
#  'aid_ZTF21abgdeov',
#  'aid_ZTF18aaywnhi',
#  'aid_ZTF18abahiry',
#  'aid_ZTF18aawbiju',
#  'aid_ZTF18acskaqa',
#  'aid_ZTF17aaadynj',
#  'aid_ZTF18adngyax',
#  'aid_ZTF17aabuleq',
#  'aid_ZTF19aabmysp',
#  'aid_ZTF19aarguhg',
#  'aid_ZTF19aadbbct',
#  'aid_ZTF17aabpwzy',
#  'aid_ZTF20aancafz',
#  'aid_ZTF18adnclwb',
#  'aid_ZTF18aazwmxa',
#  'aid_ZTF19aadadqs',
#  'aid_ZTF17aaafzma',
#  'aid_ZTF18adjsnyh',
#  'aid_ZTF18abjmrxj',
#  'aid_ZTF18aaxuixm',
#  'aid_ZTF23abccont',
#  'aid_ZTF21abvykkf',
#  'aid_ZTF18aawdoyf',
#  'aid_ZTF18adakzxe',
#  'aid_ZTF18aazutqv',
#  'aid_ZTF20aaeltoa',
#  'aid_ZTF17aaaengk',
#  'aid_ZTF21aanswls',
#  'aid_ZTF18aabpsfs',
#  'aid_ZTF18abytelj',
#  'aid_ZTF18aabkbzw',
#  'aid_ZTF21abnudtb',
#  'aid_ZTF19aapwypq',
#  'aid_ZTF21abothvq',
#  'aid_ZTF19aaahffn',
#  'aid_ZTF17aaanyhq',
#  'aid_ZTF19abcejfo',
#  'aid_ZTF18abfnnnh',
#  'aid_ZTF18aaawbit',
#  'aid_ZTF18abeakvv',
#  'aid_ZTF18aaqqlaw',
#  'aid_ZTF18actypux',
#  'aid_ZTF18aawcdch',
#  'aid_ZTF18aaaeltb',
#  'aid_ZTF18aayqgie',
#  'aid_ZTF19aaammal',
#  'aid_ZTF18abtvijp',
#  'aid_ZTF18abobptn',
#  'aid_ZTF18adakztt',
#  'aid_ZTF17aaaeqhm',
#  'aid_ZTF18acvvtgg',
#  'aid_ZTF20aazymxi',
#  'aid_ZTF18acbzytc',
#  'aid_ZTF19aayjhpe',
#  'aid_ZTF18aayhhuc',
#  'aid_ZTF18accatez',
#  'aid_ZTF19aaafqns',
#  'aid_ZTF20aaskhqw',
#  'aid_ZTF21aalokhs',
#  'aid_ZTF19aaluldf',
#  'aid_ZTF22aaygscd',
#  'aid_ZTF18abatffv',
#  'aid_ZTF18aawmdpg',
#  'aid_ZTF17aaaeihg',
#  'aid_ZTF22absxatm',
#  'aid_ZTF20acmguhf',
#  'aid_ZTF18aaoecso',
#  'aid_ZTF18aakzkvs',
#  'aid_ZTF21aaphlty',
#  'aid_ZTF18abiwqhj',
#  'aid_ZTF19aaaezgh',
#  'aid_ZTF18aanbnwb',
#  'aid_ZTF18abycika',
#  'aid_ZTF19aatuyli',
#  'aid_ZTF18abscmhv',
#  'aid_ZTF20aapxpsb',
#  'aid_ZTF18aazpvze',
#  'aid_ZTF19aayeokv',
#  'aid_ZTF18abegecr',
#  'aid_ZTF18absuppe',
#  'aid_ZTF21ablgmxs',
#  'aid_ZTF19acbpzir',
#  'aid_ZTF17aabmwpe',
#  'aid_ZTF18absmgqy',
#  'aid_ZTF18ablplga',
#  'aid_ZTF17aabonqs',
#  'aid_ZTF18aawaeji',
#  'aid_ZTF18acszjrq',
#  'aid_ZTF17aaadayn',
#  'aid_ZTF18abpozuv',
#  'aid_ZTF18aaypoor',
#  'aid_ZTF19aabhwcf',
#  'aid_ZTF18abmxaxt',
#  'aid_ZTF17aaajkzm',
#  'aid_ZTF18adkgyhb',
#  'aid_ZTF18acuelax',
#  'aid_ZTF17aabwkkz',
#  'aid_ZTF18acyuups',
#  'aid_ZTF21aaeqpjr',
#  'aid_ZTF19acvrjzd',
#  'aid_ZTF18abaphqg',
#  'aid_ZTF18aczuwxv',
#  'aid_ZTF18abblyoh',
#  'aid_ZTF18abcxijx',
#  'aid_ZTF19abkgych',
#  'aid_ZTF18actxebc',
#  'aid_ZTF18abesmud',
#  'aid_ZTF18acyoisc',
#  'aid_ZTF18aaahyks',
#  'aid_ZTF19aapbjmb',
#  'aid_ZTF19aaxlhiz',
#  'aid_ZTF18abmjhzo',
#  'aid_ZTF18aavmrsf',
#  'aid_ZTF18abbvroe',
#  'aid_ZTF18abcnvwt',
#  'aid_ZTF19abbyxmb',
#  'aid_ZTF18ablvtbc',
#  'aid_ZTF18aaxczas',
#  'aid_ZTF17aaadyug',
#  'aid_ZTF17aaadjrt',
#  'aid_ZTF18aaxlsmq',
#  'aid_ZTF20acedqis',
#  'aid_ZTF18abeaisj',
#  'aid_ZTF18acryhyt',
#  'aid_ZTF19aabzttb',
#  'aid_ZTF19aaimiox',
#  'aid_ZTF23abeqble',
#  'aid_ZTF17aabvddo',
#  'aid_ZTF19abrcunk',
#  'aid_ZTF18aaxumqj',
#  'aid_ZTF18adfaovv',
#  'aid_ZTF18aavwurv',
#  'aid_ZTF19adcyeft',
#  'aid_ZTF18aaegrnn',
#  'aid_ZTF19abyubxn',
#  'aid_ZTF18aayoxka',
#  'aid_ZTF19abflnat',
#  'aid_ZTF21aaoqcnh',
#  'aid_ZTF18acetmcg',
#  'aid_ZTF18abkhcrc',
#  'aid_ZTF21aaqwjlz',
#  'aid_ZTF18abnzadn',
#  'aid_ZTF19aavbowl',
#  'aid_ZTF17aaarlrs',
#  'aid_ZTF22abayewb',
#  'aid_ZTF18aaadsii',
#  'aid_ZTF19aatvrhz',
#  'aid_ZTF18abzsyuc',
#  'aid_ZTF18adjowbf',
#  'aid_ZTF18abaeapi',
#  'aid_ZTF18abmrmuf',
#  'aid_ZTF20aamazzl',
#  'aid_ZTF18abchkpb',
#  'aid_ZTF18abwibgz',
#  'aid_ZTF21aagsxlu',
#  'aid_ZTF18aabjdmj',
#  'aid_ZTF18aacdvjp',
#  'aid_ZTF20aacdnck',
#  'aid_ZTF18abajxex',
#  'aid_ZTF19acawhvq',
#  'aid_ZTF18aayeknl',
#  'aid_ZTF17aaakijn',
#  'aid_ZTF17aabpnoy',
#  'aid_ZTF18ablrmha',
#  'aid_ZTF19aayeqse',
#  'aid_ZTF18abdlwso',
#  'aid_ZTF19aauyuof',
#  'aid_ZTF18aczepmh',
#  'aid_ZTF20abyxnjo',
#  'aid_ZTF18aarpwgw',
#  'aid_ZTF18aaadpya',
#  'aid_ZTF18acmywit',
#  'aid_ZTF19abyjswp',
#  'aid_ZTF18abcklsi',
#  'aid_ZTF18abmsbve',
#  'aid_ZTF18aaswenp',
#  'aid_ZTF18acryfmv',
#  'aid_ZTF18aajbhml',
#  'aid_ZTF18aazfdfo',
#  'aid_ZTF18abznpys',
#  'aid_ZTF20abajxia',
#  'aid_ZTF18acvgzun',
#  'aid_ZTF21aamqgzr',
#  'aid_ZTF18abaqgwg',
#  'aid_ZTF18acszhla',
#  'aid_ZTF19acyniwk',
#  'aid_ZTF20acmmiwq',
#  'aid_ZTF18aahxqhe',
#  'aid_ZTF18abmszjn',
#  'aid_ZTF18actwwor',
#  'aid_ZTF18abehcus',
#  'aid_ZTF18aabirgq',
#  'aid_ZTF17aabpmpn',
#  'aid_ZTF17aaagazp',
#  'aid_ZTF18abilbju',
#  'aid_ZTF18abmjmro',
#  'aid_ZTF19aasiigz',
#  'aid_ZTF22aacjliw',
#  'aid_ZTF18acbzrdr',
#  'aid_ZTF18abcjwmz',
#  'aid_ZTF19aayriyj',
#  'aid_ZTF18aabggxd',
#  'aid_ZTF18abtuznd',
#  'aid_ZTF20aaflcny',
#  'aid_ZTF20aarqovi',
#  'aid_ZTF20aasiwcu',
#  'aid_ZTF19acrcuxg',
#  'aid_ZTF18acpgecw',
#  'aid_ZTF18aavqmcb',
#  'aid_ZTF20acdbjev',
#  'aid_ZTF19aayvoqc',
#  'aid_ZTF17aabuuvs',
#  'aid_ZTF18aarkchp',
#  'aid_ZTF21abiricn',
#  'aid_ZTF17aabzwvl',
#  'aid_ZTF18abuqhbk',
#  'aid_ZTF18aavzkch',
#  'aid_ZTF18acyrsoj',
#  'aid_ZTF19aavxoos',
#  'aid_ZTF18abntyqw',
#  'aid_ZTF18aazjflo',
#  'aid_ZTF18aaakpoe',
#  'aid_ZTF20abmbznv',
#  'aid_ZTF19aaycngx',
#  'aid_ZTF18absbpid',
#  'aid_ZTF18aazvibw',
#  'aid_ZTF19aaaemwo',
#  'aid_ZTF18abcvenm',
#  'aid_ZTF17aaaqlfb',
#  'aid_ZTF18actwqpm',
#  'aid_ZTF18abcvfit',
#  'aid_ZTF18adjwaai',
#  'aid_ZTF18aammmyy',
#  'aid_ZTF18abbfzeh',
#  'aid_ZTF17aabuoxa',
#  'aid_ZTF18abadlfo',
#  'aid_ZTF23aagklwb',
#  'aid_ZTF18aaabicb',
#  'aid_ZTF18abrwqxt',
#  'aid_ZTF18abnusld',
#  'aid_ZTF18aainybs',
#  ...]

# %%
predictions[predictions['shorten'] == 'None']
# Out:
#                        AGN    Blazar       CEP   CV/Nova      DSCT        EA  \
# index
# aid_ZTF17aaaocpq  0.274019  0.323965  0.008282  0.031802  0.000200  0.001479
# aid_ZTF17aaazbbb  0.545738  0.262871  0.002778  0.013270  0.000605  0.001066
# aid_ZTF17aaazlzl  0.408327  0.172802  0.004067  0.028232  0.001411  0.010718
# aid_ZTF17aaazuft  0.539812  0.193079  0.000763  0.004397  0.000230  0.000342
# aid_ZTF17aabhjci  0.266161  0.261065  0.017276  0.075081  0.000835  0.002395
# ...                    ...       ...       ...       ...       ...       ...
# aid_ZTF23aamaycf  0.084641  0.066134  0.013404  0.004160  0.000068  0.002840
# aid_ZTF23aaoscaj  0.036648  0.087262  0.045043  0.050203  0.014285  0.050833
# aid_ZTF23aappeda  0.013489  0.020425  0.051481  0.083976  0.008262  0.122116
# aid_ZTF23aazoggh  0.013716  0.031059  0.031766  0.089585  0.046332  0.048265
# aid_ZTF23abdyjve  0.038804  0.118179  0.014074  0.025008  0.001487  0.004085
#
#                      EB/EW       LPV  Microlensing  Periodic-Other  ...  \
# index                                                               ...
# aid_ZTF17aaaocpq  0.001386  0.039735      0.005580        0.002421  ...
# aid_ZTF17aaazbbb  0.000852  0.003420      0.000000        0.001888  ...
# aid_ZTF17aaazlzl  0.004368  0.006268      0.006507        0.006418  ...
# aid_ZTF17aaazuft  0.000220  0.003231      0.002192        0.001251  ...
# aid_ZTF17aabhjci  0.001740  0.010024      0.011233        0.004207  ...
# ...                    ...       ...           ...             ...  ...
# aid_ZTF23aamaycf  0.000685  0.019891      0.007628        0.001633  ...
# aid_ZTF23aaoscaj  0.026705  0.046977      0.126285        0.046988  ...
# aid_ZTF23aappeda  0.059358  0.012554      0.180265        0.026806  ...
# aid_ZTF23aazoggh  0.038729  0.013705      0.059407        0.106097  ...
# aid_ZTF23abdyjve  0.002749  0.113788      0.058715        0.009692  ...
#
#                      RSCVn      SLSN      SNII     SNIIb     SNIIn      SNIa  \
# index
# aid_ZTF17aaaocpq  0.004218  0.001649  0.001029  0.000231  0.002013  0.000731
# aid_ZTF17aaazbbb  0.003893  0.001148  0.000738  0.000394  0.001331  0.000527
# aid_ZTF17aaazlzl  0.007182  0.012353  0.022126  0.013199  0.028323  0.028211
# aid_ZTF17aaazuft  0.001155  0.001676  0.002415  0.001360  0.004359  0.003671
# aid_ZTF17aabhjci  0.008311  0.013555  0.016964  0.007551  0.034272  0.021647
# ...                    ...       ...       ...       ...       ...       ...
# aid_ZTF23aamaycf  0.007985  0.000499  0.000885  0.000295  0.000910  0.001292
# aid_ZTF23aaoscaj  0.055265  0.039126  0.015003  0.004889  0.022219  0.016454
# aid_ZTF23aappeda  0.033176  0.013771  0.008689  0.004237  0.012859  0.005574
# aid_ZTF23aazoggh  0.110053  0.009523  0.009256  0.005107  0.009795  0.009538
# aid_ZTF23abdyjve  0.004632  0.007812  0.001861  0.000577  0.003529  0.001904
#
#                      SNIbc       TDE       YSO  shorten
# index
# aid_ZTF17aaaocpq  0.000421  0.000936  0.231688     None
# aid_ZTF17aaazbbb  0.000352  0.000807  0.090415     None
# aid_ZTF17aaazlzl  0.021079  0.019514  0.157944     None
# aid_ZTF17aaazuft  0.002460  0.001648  0.145894     None
# aid_ZTF17aabhjci  0.011502  0.034253  0.133264     None
# ...                    ...       ...       ...      ...
# aid_ZTF23aamaycf  0.000806  0.000524  0.758198     None
# aid_ZTF23aaoscaj  0.007513  0.029824  0.235021     None
# aid_ZTF23aappeda  0.009469  0.012581  0.259119     None
# aid_ZTF23aazoggh  0.009527  0.007924  0.300741     None
# aid_ZTF23abdyjve  0.002140  0.003580  0.483174     None
#
# [41687 rows x 23 columns]

# %%
atat_pred_2048_time_test = predictions[predictions['shorten'] == 'None']
atat_pred_2048_time_test = atat_pred_2048_time_test.reindex(obj_label)[sort_classes]
atat_pred_2048_time_test
# Out:
#                        AGN    Blazar       CEP   CV/Nova      DSCT        EA  \
# index
# aid_ZTF18abnukht  0.001725  0.001185  0.038822  0.025608  0.024564  0.688700
# aid_ZTF17aabxfzy  0.000892  0.001666  0.008862  0.037268  0.004571  0.001558
# aid_ZTF18aazwmdx  0.018508  0.033984  0.047536  0.051402  0.019439  0.144631
# aid_ZTF19aclfauc  0.006875  0.006907  0.285207  0.053663  0.092366  0.046204
# aid_ZTF18aaodyyn  0.000339  0.001194  0.033158  0.020241  0.017579  0.012119
# ...                    ...       ...       ...       ...       ...       ...
# aid_ZTF18aazemmw  0.008918  0.013335  0.012377  0.012607  0.000014  0.005762
# aid_ZTF18aaaeino  0.000123  0.000325  0.033406  0.015012  0.221195  0.019050
# aid_ZTF19aaadnhb  0.002397  0.004056  0.042449  0.063926  0.114953  0.307299
# aid_ZTF18acrhela  0.446236  0.239490  0.007230  0.020305  0.000795  0.003092
# aid_ZTF18abbgbyc  0.008849  0.009853  0.032566  0.160424  0.120164  0.124789
#
#                      EB/EW       LPV  Microlensing  Periodic-Other  ...  \
# index                                                               ...
# aid_ZTF18abnukht  0.083110  0.008891      0.000758        0.026607  ...
# aid_ZTF17aabxfzy  0.013720  0.000218      0.001578        0.021416  ...
# aid_ZTF18aazwmdx  0.058621  0.011143      0.175964        0.043574  ...
# aid_ZTF19aclfauc  0.071676  0.048164      0.009544        0.140359  ...
# aid_ZTF18aaodyyn  0.009223  0.001508      0.001664        0.012496  ...
# ...                    ...       ...           ...             ...  ...
# aid_ZTF18aazemmw  0.002695  0.010696      0.003896        0.001407  ...
# aid_ZTF18aaaeino  0.126266  0.002626      0.000292        0.084780  ...
# aid_ZTF19aaadnhb  0.164237  0.007719      0.002025        0.088632  ...
# aid_ZTF18acrhela  0.003006  0.011718      0.009323        0.005334  ...
# aid_ZTF18abbgbyc  0.064509  0.011909      0.004055        0.067947  ...
#
#                      RSCVn      SLSN      SNII     SNIIb     SNIIn      SNIa  \
# index
# aid_ZTF18abnukht  0.039902  0.001164  0.001755  0.000989  0.002040  0.002365
# aid_ZTF17aabxfzy  0.008998  0.007581  0.005660  0.001547  0.006492  0.002925
# aid_ZTF18aazwmdx  0.061423  0.016867  0.007410  0.004254  0.017537  0.004074
# aid_ZTF19aclfauc  0.070453  0.006937  0.005106  0.003066  0.007094  0.006191
# aid_ZTF18aaodyyn  0.003859  0.000654  0.000375  0.000122  0.000405  0.000261
# ...                    ...       ...       ...       ...       ...       ...
# aid_ZTF18aazemmw  0.002673  0.001026  0.000544  0.000163  0.000847  0.000381
# aid_ZTF18aaaeino  0.012726  0.000056  0.000068  0.000027  0.000078  0.000087
# aid_ZTF19aaadnhb  0.058978  0.001578  0.001391  0.001012  0.001915  0.001682
# aid_ZTF18acrhela  0.004923  0.005380  0.002800  0.000895  0.006096  0.001715
# aid_ZTF18abbgbyc  0.111687  0.000857  0.000777  0.000654  0.000993  0.001335
#
#                      SNIbc       TDE       YSO  shorten
# index
# aid_ZTF18abnukht  0.001283  0.002959  0.028519     None
# aid_ZTF17aabxfzy  0.002946  0.005346  0.007382     None
# aid_ZTF18aazwmdx  0.004188  0.015846  0.192507     None
# aid_ZTF19aclfauc  0.003640  0.004111  0.043637     None
# aid_ZTF18aaodyyn  0.000218  0.000602  0.002968     None
# ...                    ...       ...       ...      ...
# aid_ZTF18aazemmw  0.000392  0.000611  0.916537     None
# aid_ZTF18aaaeino  0.000036  0.000106  0.004496     None
# aid_ZTF19aaadnhb  0.001165  0.001520  0.037932     None
# aid_ZTF18acrhela  0.002083  0.003722  0.099802     None
# aid_ZTF18abbgbyc  0.000596  0.001913  0.223905     None
#
# [8328 rows x 23 columns]

# %%
atat_pred_2048_time_test
# Out:
#                        AGN    Blazar       CEP   CV/Nova      DSCT        EA  \
# index
# aid_ZTF18abnukht  0.001725  0.001185  0.038822  0.025608  0.024564  0.688700
# aid_ZTF17aabxfzy  0.000892  0.001666  0.008862  0.037268  0.004571  0.001558
# aid_ZTF18aazwmdx  0.018508  0.033984  0.047536  0.051402  0.019439  0.144631
# aid_ZTF19aclfauc  0.006875  0.006907  0.285207  0.053663  0.092366  0.046204
# aid_ZTF18aaodyyn  0.000339  0.001194  0.033158  0.020241  0.017579  0.012119
# ...                    ...       ...       ...       ...       ...       ...
# aid_ZTF18aazemmw  0.008918  0.013335  0.012377  0.012607  0.000014  0.005762
# aid_ZTF18aaaeino  0.000123  0.000325  0.033406  0.015012  0.221195  0.019050
# aid_ZTF19aaadnhb  0.002397  0.004056  0.042449  0.063926  0.114953  0.307299
# aid_ZTF18acrhela  0.446236  0.239490  0.007230  0.020305  0.000795  0.003092
# aid_ZTF18abbgbyc  0.008849  0.009853  0.032566  0.160424  0.120164  0.124789
#
#                      EB/EW       LPV  Microlensing  Periodic-Other  ...  \
# index                                                               ...
# aid_ZTF18abnukht  0.083110  0.008891      0.000758        0.026607  ...
# aid_ZTF17aabxfzy  0.013720  0.000218      0.001578        0.021416  ...
# aid_ZTF18aazwmdx  0.058621  0.011143      0.175964        0.043574  ...
# aid_ZTF19aclfauc  0.071676  0.048164      0.009544        0.140359  ...
# aid_ZTF18aaodyyn  0.009223  0.001508      0.001664        0.012496  ...
# ...                    ...       ...           ...             ...  ...
# aid_ZTF18aazemmw  0.002695  0.010696      0.003896        0.001407  ...
# aid_ZTF18aaaeino  0.126266  0.002626      0.000292        0.084780  ...
# aid_ZTF19aaadnhb  0.164237  0.007719      0.002025        0.088632  ...
# aid_ZTF18acrhela  0.003006  0.011718      0.009323        0.005334  ...
# aid_ZTF18abbgbyc  0.064509  0.011909      0.004055        0.067947  ...
#
#                      RSCVn      SLSN      SNII     SNIIb     SNIIn      SNIa  \
# index
# aid_ZTF18abnukht  0.039902  0.001164  0.001755  0.000989  0.002040  0.002365
# aid_ZTF17aabxfzy  0.008998  0.007581  0.005660  0.001547  0.006492  0.002925
# aid_ZTF18aazwmdx  0.061423  0.016867  0.007410  0.004254  0.017537  0.004074
# aid_ZTF19aclfauc  0.070453  0.006937  0.005106  0.003066  0.007094  0.006191
# aid_ZTF18aaodyyn  0.003859  0.000654  0.000375  0.000122  0.000405  0.000261
# ...                    ...       ...       ...       ...       ...       ...
# aid_ZTF18aazemmw  0.002673  0.001026  0.000544  0.000163  0.000847  0.000381
# aid_ZTF18aaaeino  0.012726  0.000056  0.000068  0.000027  0.000078  0.000087
# aid_ZTF19aaadnhb  0.058978  0.001578  0.001391  0.001012  0.001915  0.001682
# aid_ZTF18acrhela  0.004923  0.005380  0.002800  0.000895  0.006096  0.001715
# aid_ZTF18abbgbyc  0.111687  0.000857  0.000777  0.000654  0.000993  0.001335
#
#                      SNIbc       TDE       YSO  shorten
# index
# aid_ZTF18abnukht  0.001283  0.002959  0.028519     None
# aid_ZTF17aabxfzy  0.002946  0.005346  0.007382     None
# aid_ZTF18aazwmdx  0.004188  0.015846  0.192507     None
# aid_ZTF19aclfauc  0.003640  0.004111  0.043637     None
# aid_ZTF18aaodyyn  0.000218  0.000602  0.002968     None
# ...                    ...       ...       ...      ...
# aid_ZTF18aazemmw  0.000392  0.000611  0.916537     None
# aid_ZTF18aaaeino  0.000036  0.000106  0.004496     None
# aid_ZTF19aaadnhb  0.001165  0.001520  0.037932     None
# aid_ZTF18acrhela  0.002083  0.003722  0.099802     None
# aid_ZTF18abbgbyc  0.000596  0.001913  0.223905     None
#
# [8328 rows x 23 columns]

# %%
atat_pred_2048_time_test.isnull().sum()
# Out:
# AGN               0
# Blazar            0
# CEP               0
# CV/Nova           0
# DSCT              0
# EA                0
# EB/EW             0
# LPV               0
# Microlensing      0
# Periodic-Other    0
# QSO               0
# RRLab             0
# RRLc              0
# RSCVn             0
# SLSN              0
# SNII              0
# SNIIb             0
# SNIIn             0
# SNIa              0
# SNIbc             0
# TDE               0
# YSO               0
# shorten           0
# dtype: int64

# %%
#nan_rows = atat_pred_2048_time_test[atat_pred_2048_time_test.isna().any(axis=1)]
#nan_indices = nan_rows.index
#print(nan_indices)

# %%
#position = obj_label.index(nan_indices[0])
#position

# %%
atat_pred_2048_time_test
# Out:
#                        AGN    Blazar       CEP   CV/Nova      DSCT        EA  \
# index
# aid_ZTF18abnukht  0.001725  0.001185  0.038822  0.025608  0.024564  0.688700
# aid_ZTF17aabxfzy  0.000892  0.001666  0.008862  0.037268  0.004571  0.001558
# aid_ZTF18aazwmdx  0.018508  0.033984  0.047536  0.051402  0.019439  0.144631
# aid_ZTF19aclfauc  0.006875  0.006907  0.285207  0.053663  0.092366  0.046204
# aid_ZTF18aaodyyn  0.000339  0.001194  0.033158  0.020241  0.017579  0.012119
# ...                    ...       ...       ...       ...       ...       ...
# aid_ZTF18aazemmw  0.008918  0.013335  0.012377  0.012607  0.000014  0.005762
# aid_ZTF18aaaeino  0.000123  0.000325  0.033406  0.015012  0.221195  0.019050
# aid_ZTF19aaadnhb  0.002397  0.004056  0.042449  0.063926  0.114953  0.307299
# aid_ZTF18acrhela  0.446236  0.239490  0.007230  0.020305  0.000795  0.003092
# aid_ZTF18abbgbyc  0.008849  0.009853  0.032566  0.160424  0.120164  0.124789
#
#                      EB/EW       LPV  Microlensing  Periodic-Other  ...  \
# index                                                               ...
# aid_ZTF18abnukht  0.083110  0.008891      0.000758        0.026607  ...
# aid_ZTF17aabxfzy  0.013720  0.000218      0.001578        0.021416  ...
# aid_ZTF18aazwmdx  0.058621  0.011143      0.175964        0.043574  ...
# aid_ZTF19aclfauc  0.071676  0.048164      0.009544        0.140359  ...
# aid_ZTF18aaodyyn  0.009223  0.001508      0.001664        0.012496  ...
# ...                    ...       ...           ...             ...  ...
# aid_ZTF18aazemmw  0.002695  0.010696      0.003896        0.001407  ...
# aid_ZTF18aaaeino  0.126266  0.002626      0.000292        0.084780  ...
# aid_ZTF19aaadnhb  0.164237  0.007719      0.002025        0.088632  ...
# aid_ZTF18acrhela  0.003006  0.011718      0.009323        0.005334  ...
# aid_ZTF18abbgbyc  0.064509  0.011909      0.004055        0.067947  ...
#
#                      RSCVn      SLSN      SNII     SNIIb     SNIIn      SNIa  \
# index
# aid_ZTF18abnukht  0.039902  0.001164  0.001755  0.000989  0.002040  0.002365
# aid_ZTF17aabxfzy  0.008998  0.007581  0.005660  0.001547  0.006492  0.002925
# aid_ZTF18aazwmdx  0.061423  0.016867  0.007410  0.004254  0.017537  0.004074
# aid_ZTF19aclfauc  0.070453  0.006937  0.005106  0.003066  0.007094  0.006191
# aid_ZTF18aaodyyn  0.003859  0.000654  0.000375  0.000122  0.000405  0.000261
# ...                    ...       ...       ...       ...       ...       ...
# aid_ZTF18aazemmw  0.002673  0.001026  0.000544  0.000163  0.000847  0.000381
# aid_ZTF18aaaeino  0.012726  0.000056  0.000068  0.000027  0.000078  0.000087
# aid_ZTF19aaadnhb  0.058978  0.001578  0.001391  0.001012  0.001915  0.001682
# aid_ZTF18acrhela  0.004923  0.005380  0.002800  0.000895  0.006096  0.001715
# aid_ZTF18abbgbyc  0.111687  0.000857  0.000777  0.000654  0.000993  0.001335
#
#                      SNIbc       TDE       YSO  shorten
# index
# aid_ZTF18abnukht  0.001283  0.002959  0.028519     None
# aid_ZTF17aabxfzy  0.002946  0.005346  0.007382     None
# aid_ZTF18aazwmdx  0.004188  0.015846  0.192507     None
# aid_ZTF19aclfauc  0.003640  0.004111  0.043637     None
# aid_ZTF18aaodyyn  0.000218  0.000602  0.002968     None
# ...                    ...       ...       ...      ...
# aid_ZTF18aazemmw  0.000392  0.000611  0.916537     None
# aid_ZTF18aaaeino  0.000036  0.000106  0.004496     None
# aid_ZTF19aaadnhb  0.001165  0.001520  0.037932     None
# aid_ZTF18acrhela  0.002083  0.003722  0.099802     None
# aid_ZTF18abbgbyc  0.000596  0.001913  0.223905     None
#
# [8328 rows x 23 columns]

# %%
y_pred_test = atat_pred_2048_time_test.drop(['shorten'], axis=1).idxmax(axis=1).values
#y_pred_test = atat_pred_2048_time_test.idxmax(axis=1).values
y_pred_test
# Out:
# array(['EA', 'RRLc', 'YSO', ..., 'EA', 'AGN', 'YSO'], dtype=object)

# %%
#y_real_test = np.delete(y_real_test, position)
#y_real_test

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

fs = 12

cm = confusion_matrix(y_true=y_real_test, y_pred=y_pred_test, labels=order_classes, normalize='true')

cmap = plt.cm.Blues
fig, ax = plt.subplots(figsize=(11, 11)) #, dpi=110)
im = ax.imshow(np.around(cm, decimals=2), interpolation='nearest', cmap=cmap)

# color map
new_color = cmap(1.0) 

# Añadiendo manualmente las anotaciones con la media y desviación estándar
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        if cm[i, j] >= 0.005:
            #print(cm[i, j])
            text = f'{np.around(cm[i, j], decimals=2)}'
            color = "white" if cm[i, j] > 0.5 else new_color  # Blanco para la diagonal, tono de azul para otras celdas
            ax.text(j, i, text, ha="center", va="center", color=color, fontsize=fs)
        else:
            text = f'{np.around(cm[i, j], decimals=2)}'
            color = "white" if cm[i, j] > 0.5 else new_color  # Blanco para la diagonal, tono de azul para otras celdas
            ax.text(j, i, text, ha="center", va="center", color=color, fontsize=fs)

# Ajustes finales y mostrar la gráfica
ax.tick_params(axis='both', which='major', labelsize=12)
ax.set_xticks(np.arange(len(order_classes)))
ax.set_yticks(np.arange(len(order_classes)))
ax.set_xticklabels(order_classes)
ax.set_yticklabels(order_classes)
plt.setp(ax.get_xticklabels(), rotation=90, ha="right", rotation_mode="anchor")

ax.set_title('HBRF', fontsize=16, pad=13)
ax.set_xlabel('Predicted label', fontsize=16, labelpad=13)  # Label del eje x
ax.set_ylabel('True label', fontsize=16, labelpad=13)        # Label del eje y

ax.xaxis.label.set_size(16)
ax.yaxis.label.set_size(16)
ax.xaxis.labelpad = 13
ax.yaxis.labelpad = 13

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

f1_score(y_real_test, y_pred_test, average='macro')
# Out:
# 0.6783764944030493

# %%
class_hierarchy = {
    "transient": [
        "SNIa", 
        "SNIbc", 
        "SNIIb", 
        "SNII", 
        "SNIIn", 
        "SLSN", 
        "TDE"
        ],
    "periodic": [
        "LPV",
        "EA",
        "EB/EW",
        "Periodic-Other",
        "RSCVn",
        "CEP",
        "RRLab",
        "RRLc",
        "DSCT",
    ],
    "stochastic": [
        "QSO",
        "AGN",
        "Blazar",
        "YSO",
        "CV/Nova",
        "Microlensing",  # ulens get confused with stochastic classes
    ],
}

# %%
# Generating the classification report.
report = classification_report(y_real_test, y_pred_test, output_dict=True)
report_df = pd.DataFrame(report).T.loc[order_classes + ['macro avg', 'weighted avg']]
report_df['support'] = report_df['support'].astype(int)
report_df[["precision", "recall", "f1-score"]] = report_df[["precision", "recall", "f1-score"]].map(lambda x: round(x, 3))

# Mostrar el reporte actualizado.
report_df
# Out:
#                 precision  recall  f1-score  support
# SNIa                0.860   0.684     0.762      599
# SNIbc               0.323   0.464     0.381      110
# SNIIb               0.333   0.231     0.273       26
# SNII                0.711   0.645     0.676      321
# SNIIn               0.263   0.417     0.323       60
# SLSN                0.350   0.683     0.463       41
# TDE                 0.230   0.824     0.359       17
# Microlensing        0.222   0.571     0.320        7
# QSO                 0.866   0.843     0.854      599
# AGN                 0.841   0.753     0.795      596
# Blazar              0.678   0.827     0.745      295
# YSO                 0.785   0.844     0.813      596
# CV/Nova             0.768   0.887     0.824      355
# LPV                 0.939   0.932     0.935      599
# EA                  0.863   0.785     0.822      600
# EB/EW               0.808   0.780     0.794      600
# Periodic-Other      0.577   0.534     0.555      266
# RSCVn               0.739   0.827     0.780      513
# CEP                 0.866   0.754     0.806      598
# RRLab               0.894   0.923     0.908      600
# RRLc                0.891   0.883     0.887      599
# DSCT                0.854   0.846     0.850      331
# macro avg           0.666   0.724     0.678     8328
# weighted avg        0.811   0.797     0.801     8328

# %%
# DataFrame para almacenar el reporte ponderado por clase
weighted_report = pd.DataFrame(columns=["precision", "recall", "f1-score", "support"], index=order_classes)

# Calcular el reporte ponderado por cada clase
for cls in order_classes:
    support_cls = report_df.loc[cls, 'support']
    other_classes = [c for c in order_classes if c != cls]

    # Calcular soporte total de las otras clases
    total_support = report_df.loc[other_classes, 'support'].sum()

    # Calcular métricas ponderadas para cada clase
    weighted_precision = (report_df.loc[other_classes, 'precision'] * report_df.loc[other_classes, 'support']).sum() / total_support
    weighted_recall = (report_df.loc[other_classes, 'recall'] * report_df.loc[other_classes, 'support']).sum() / total_support
    weighted_f1 = (report_df.loc[other_classes, 'f1-score'] * report_df.loc[other_classes, 'support']).sum() / total_support

    # Asignar los valores al DataFrame
    weighted_report.loc[cls] = [round(weighted_precision, 3), round(weighted_recall, 3), round(weighted_f1, 3), support_cls]

# Convertir a tipo int la columna support
weighted_report['support'] = weighted_report['support'].astype(int)
weighted_report
# Out:
#                precision recall f1-score  support
# SNIa               0.807  0.806    0.804      599
# SNIbc              0.817  0.801    0.806      110
# SNIIb              0.812  0.799    0.802       26
# SNII               0.815  0.803    0.806      321
# SNIIn              0.815    0.8    0.804       60
# SLSN               0.813  0.798    0.802       41
# TDE                0.812  0.797    0.802       17
# Microlensing       0.811  0.797    0.801        7
# QSO                0.806  0.793    0.797      599
# AGN                0.808    0.8    0.801      596
# Blazar             0.816  0.796    0.803      295
# YSO                0.813  0.793      0.8      596
# CV/Nova            0.813  0.793      0.8      355
# LPV                0.801  0.787     0.79      599
# EA                 0.807  0.798    0.799      600
# EB/EW              0.811  0.798    0.801      600
# Periodic-Other     0.818  0.806    0.809      266
# RSCVn              0.815  0.795    0.802      513
# CEP                0.806    0.8      0.8      598
# RRLab              0.804  0.787    0.792      600
# RRLc               0.805   0.79    0.794      599
# DSCT               0.809  0.795    0.799      331

# %%
def average_metric(class_group, report, metric):
    values = [report[label][metric] for label in class_group if label in report]
    return np.mean(values)

# Calculating average precision and F1-score for each category
transient_precision = average_metric(class_hierarchy["transient"], report, "precision")
periodic_precision = average_metric(class_hierarchy["periodic"], report, "precision")
stochastic_precision = average_metric(class_hierarchy["stochastic"], report, "precision")

transient_recall = average_metric(class_hierarchy["transient"], report, "recall")
periodic_recall = average_metric(class_hierarchy["periodic"], report, "recall")
stochastic_recall = average_metric(class_hierarchy["stochastic"], report, "recall")

transient_f1 = average_metric(class_hierarchy["transient"], report, "f1-score")
periodic_f1 = average_metric(class_hierarchy["periodic"], report, "f1-score")
stochastic_f1 = average_metric(class_hierarchy["stochastic"], report, "f1-score")

# Creating a DataFrame for the results, matching the order of the classification report (precision, recall, f1-score).
results_df_hier = pd.DataFrame({
    "precision": [
        transient_precision,
        periodic_precision,
        stochastic_precision
    ],
    "recall": [
        transient_recall,
        periodic_recall,
        stochastic_recall
    ],
    "f1-score": [
        transient_f1,
        periodic_f1,
        stochastic_f1
    ]
}, index=["Transient", "Periodic", "Stochastic"])

# Formatting the DataFrame to display three decimal places
results_df_hier = results_df_hier.round(3)

# Updating the DataFrame with the support column.
def total_support(class_group, report):
    supports = [report[label]["support"] for label in class_group if label in report]
    return sum(supports)

transient_support = total_support(class_hierarchy["transient"], report)
periodic_support = total_support(class_hierarchy["periodic"], report)
stochastic_support = total_support(class_hierarchy["stochastic"], report)
results_df_hier["support"] = [transient_support, periodic_support, stochastic_support]
results_df_hier['support'] = results_df_hier['support'].astype(int)
results_df_hier
# Out:
#             precision  recall  f1-score  support
# Transient       0.439   0.564     0.462     1174
# Periodic        0.826   0.807     0.815     4706
# Stochastic      0.693   0.788     0.725     2448

# %%
# Function to calculate the weighted average for a given metric based on support.
def weighted_average_metric(class_group, report, metric):
    # Extracting values and their corresponding supports
    values = [report[label][metric] for label in class_group if label in report]
    supports = [report[label]["support"] for label in class_group if label in report]
    # Calculating the weighted average
    weighted_avg = np.average(values, weights=supports)
    return weighted_avg

# Calculating weighted average precision, recall, and F1-score for each category.
transient_precision = weighted_average_metric(class_hierarchy["transient"], report, "precision")
periodic_precision = weighted_average_metric(class_hierarchy["periodic"], report, "precision")
stochastic_precision = weighted_average_metric(class_hierarchy["stochastic"], report, "precision")

transient_recall = weighted_average_metric(class_hierarchy["transient"], report, "recall")
periodic_recall = weighted_average_metric(class_hierarchy["periodic"], report, "recall")
stochastic_recall = weighted_average_metric(class_hierarchy["stochastic"], report, "recall")

transient_f1 = weighted_average_metric(class_hierarchy["transient"], report, "f1-score")
periodic_f1 = weighted_average_metric(class_hierarchy["periodic"], report, "f1-score")
stochastic_f1 = weighted_average_metric(class_hierarchy["stochastic"], report, "f1-score")

# Creating a DataFrame for the results, matching the order of the classification report (precision, recall, f1-score).
results_df_hier = pd.DataFrame({
    "precision": [
        transient_precision,
        periodic_precision,
        stochastic_precision
    ],
    "recall": [
        transient_recall,
        periodic_recall,
        stochastic_recall
    ],
    "f1-score": [
        transient_f1,
        periodic_f1,
        stochastic_f1
    ]
}, index=["Transient", "Periodic", "Stochastic"])

# Formatting the DataFrame to display three decimal places
results_df_hier = results_df_hier.round(3)

# Calculating total support for each category.
transient_support = total_support(class_hierarchy["transient"], report)
periodic_support = total_support(class_hierarchy["periodic"], report)
stochastic_support = total_support(class_hierarchy["stochastic"], report)

# Updating the DataFrame with the support column.
results_df_hier["support"] = [transient_support, periodic_support, stochastic_support]
results_df_hier["support"] = results_df_hier["support"].astype(int)

# Displaying the final DataFrame
results_df_hier
# Out:
#             precision  recall  f1-score  support
# Transient       0.700   0.631     0.653     1174
# Periodic        0.843   0.824     0.832     4706
# Stochastic      0.801   0.825     0.811     2448

# %%
from scipy.stats import entropy

# %%
plt.hist(entropy(atat_pred_2048_time_test, axis=1), bins=50);
plt.xlabel('entropy')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 plt.hist(entropy(atat_pred_2048_time_test, axis=1), bins=50);
#       2 plt.xlabel('entropy')
#
# File ~/.virtualenvs/ATAT_ALeRCE/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:563, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     560     contains_nan = False  # behave like there are no NaNs
#     562 if vectorized and not contains_nan and not sentinel:
# --> 563     res = hypotest_fun_out(*samples, axis=axis, **kwds)
#     564     res = result_to_tuple(res)
#     565     res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File ~/.virtualenvs/ATAT_ALeRCE/lib/python3.10/site-packages/scipy/stats/_entropy.py:144, in entropy(pk, qk, base, axis)
#     142 pk = np.asarray(pk)
#     143 with np.errstate(invalid='ignore'):
# --> 144     pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#     145 if qk is None:
#     146     vec = special.entr(pk)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
plt.hist(atat_pred_2048_time_test.max(axis=1), bins=50)
plt.xlabel('highest prob')
# Out:
# Text(0.5, 0, 'highest prob')

# %%
cm.shape
# Out:
# (22, 22)

# %%
# Create a mapping from class names to their indices based on the order in `order_classes`
class_indices = {class_name: idx for idx, class_name in enumerate(order_classes)}
class_indices
# Out:
# {'SNIa': 0,
#  'SNIbc': 1,
#  'SNIIb': 2,
#  'SNII': 3,
#  'SNIIn': 4,
#  'SLSN': 5,
#  'TDE': 6,
#  'Microlensing': 7,
#  'QSO': 8,
#  'AGN': 9,
#  'Blazar': 10,
#  'YSO': 11,
#  'CV/Nova': 12,
#  'LPV': 13,
#  'EA': 14,
#  'EB/EW': 15,
#  'Periodic-Other': 16,
#  'RSCVn': 17,
#  'CEP': 18,
#  'RRLab': 19,
#  'RRLc': 20,
#  'DSCT': 21}

# %%
# Initialize the 3x3 matrix for the grouped confusion matrix
conf_matrix_3x3 = np.zeros((3, 3))

# Mapping of group names to matrix indices
group_indices = {'transient': 0, 'periodic': 1, 'stochastic': 2}
group_labels = group_indices.keys()

# Aggregate values into the 3x3 matrix based on `class_hierarchy`
for group_row, classes_row in class_hierarchy.items():
    for group_col, classes_col in class_hierarchy.items():
        row_index = group_indices[group_row]
        col_index = group_indices[group_col]

        # Get indices for current row and column groups
        row_indices = [class_indices[class_name] for class_name in classes_row if class_name in class_indices]
        col_indices = [class_indices[class_name] for class_name in classes_col if class_name in class_indices]

        # Sum values in the specified row and column ranges of the original confusion matrix
        conf_matrix_3x3[row_index, col_index] = cm[np.ix_(row_indices, col_indices)].sum()

# Display the resulting 3x3 confusion matrix
print("Aggregated Confusion Matrix:\n", conf_matrix_3x3)
# Out:
# Aggregated Confusion Matrix:
#  [[6.86981327e+00 0.00000000e+00 1.30186733e-01]
#  [5.01393069e-03 8.62169505e+00 3.73291024e-01]
#  [4.82453697e-01 1.71216570e-01 5.34632973e+00]]

# %%
import seaborn as sns

# Normalize the aggregated 3x3 confusion matrix by row (true class)
conf_matrix_3x3_normalized = conf_matrix_3x3 / conf_matrix_3x3.sum(axis=1, keepdims=True)

# Plotting the normalized 3x3 confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_3x3_normalized, annot=True, fmt=".2f", cmap="Blues", xticklabels=group_labels, yticklabels=group_labels)
plt.title("Normalized Aggregated Confusion Matrix")
plt.xlabel("Predicted Group")
plt.ylabel("True Group")
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

# Map each class name to its group label
group_mapping = {class_name: "transient" for class_name in class_hierarchy["transient"]}
group_mapping.update({class_name: "periodic" for class_name in class_hierarchy["periodic"]})
group_mapping.update({class_name: "stochastic" for class_name in class_hierarchy["stochastic"]})

# Convert y_real_test and y_pred_test to group labels
y_real_group = np.array([group_mapping[label] for label in y_real_test])
y_pred_group = np.array([group_mapping[label] for label in y_pred_test])

# Define group labels for reporting
group_labels = ["transient", "periodic", "stochastic"]

# Calculate macro-averaged metrics for each group
metrics = {}
for group in group_labels:
    # Mask for true positives in the current group
    y_true_binary = (y_real_group == group).astype(int)
    y_pred_binary = (y_pred_group == group).astype(int)
    
    precision = precision_score(y_true_binary, y_pred_binary, zero_division=0)
    recall = recall_score(y_true_binary, y_pred_binary, zero_division=0)
    f1 = f1_score(y_true_binary, y_pred_binary, zero_division=0)
    
    # Storing metrics in the dictionary
    metrics[group] = {
        "precision": round(precision, 3),
        "recall": round(recall, 3),
        "f1-score": round(f1, 3),
        "support": int(np.sum(y_true_binary))
    }

# Creating a DataFrame for the results to match the classification report format
classification_report_df = pd.DataFrame(metrics).T
classification_report_df = classification_report_df[["precision", "recall", "f1-score", "support"]]

# Calculating macro-averaged metrics
macro_precision = np.mean(classification_report_df["precision"])
macro_recall = np.mean(classification_report_df["recall"])
macro_f1 = np.mean(classification_report_df["f1-score"])
macro_support = classification_report_df["support"].sum()

# Adding macro averages to the DataFrame
classification_report_df.loc["macro avg"] = [round(macro_precision, 3), round(macro_recall, 3), round(macro_f1, 3), macro_support]
classification_report_df["support"] = classification_report_df["support"].astype(int)

# Displaying the final classification report-style DataFrame
classification_report_df
# Out:
#             precision  recall  f1-score  support
# transient       0.975   0.980     0.977     1174
# periodic        0.980   0.958     0.969     4706
# stochastic      0.915   0.951     0.933     2448
# macro avg       0.957   0.963     0.960     8328

# %%
# Recall a partir de la matriz de confusión agregada
recall_transient_matrix = conf_matrix_3x3[0, 0] / conf_matrix_3x3[0, :].sum()

# Recall del reporte de clasificación
recall_transient_report = classification_report_df.loc["stochastic", "recall"]

print(f"Recall (Matriz de Confusión): {recall_transient_matrix:.3f}")
print(f"Recall (Reporte de Clasificación): {recall_transient_report:.3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 2
#       1 # Recall a partir de la matriz de confusión agregada
# ----> 2 recall_transient_matrix = conf_matrix_3x3[0, 0] / conf_matrix_3x3[0, :].sum()
#       4 # Recall del reporte de clasificación
#       5 recall_transient_report = classification_report_df.loc["stochastic", "recall"]
#
# NameError: name 'conf_matrix_3x3' is not defined

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import numpy as np
import pandas as pd

# Map each class name to its group label
group_mapping = {class_name: "transient" for class_name in class_hierarchy["transient"]}
group_mapping.update({class_name: "periodic" for class_name in class_hierarchy["periodic"]})
group_mapping.update({class_name: "stochastic" for class_name in class_hierarchy["stochastic"]})

# Convert y_real_test and y_pred_test to group labels
y_real_group = np.array([group_mapping[label] for label in y_real_test])
y_pred_group = np.array([group_mapping[label] for label in y_pred_test])

# Define group labels for reporting
group_labels = ["transient", "periodic", "stochastic"]

# Generate confusion matrix at the group level
group_conf_matrix = confusion_matrix(y_real_group, y_pred_group, labels=group_labels)

# Calculate recall directly from the group-level confusion matrix
recalls = {}
for i, group in enumerate(group_labels):
    tp = group_conf_matrix[i, i]
    fn = group_conf_matrix[i, :].sum() - tp
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    recalls[group] = round(recall, 3)

# Display the results
print("Recall based on group-level confusion matrix:", recalls)

# Optional: Create a DataFrame for a detailed classification report
classification_report_df = pd.DataFrame({
    "recall": [recalls[group] for group in group_labels]
}, index=group_labels)

classification_report_df
# Out:
# Recall based on group-level confusion matrix: {'transient': 0.98, 'periodic': 0.958, 'stochastic': 0.951}
#             recall
# transient    0.980
# periodic     0.958
# stochastic   0.951
